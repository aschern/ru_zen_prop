# %%
from IPython.core.display import display, HTML
display(HTML(open('visualization/highlight.css').read()))
display(HTML(open('visualization/highlight.js').read()))

import visualization
from termcolor import colored

from collections import defaultdict
import numpy as np
import spacy
nlp = spacy.load("ru_core_news_sm")
# Out:
# <style>
#
# .highlight {
#   border: 2px solid;
#   color: #232323;
#   margin: 4px 6px 4px 3px;
#   vertical-align: middle;
#   box-shadow: 2px 4px 20px rgba(0,0,0,0.1);
#   position: relative;
#   cursor: default;
#   min-width: 26px;
#   line-height: 22px;
#   display: inline-flex;
# }
#
# .highlight:last-child {
#   margin-right: 4px;
# }
#
# .highlight:first-child {
#   margin-left: 0;
# }
#
# .highlight,
# .highlight span {
#   transition: background-color .1s ease,
#               color .1s ease,
#               box-shadow .1s ease,
#               opacity .1s ease;
# }
#
# .highlight.short-text {
#   text-align: center;
# }
#
# .highlight__label {
#   align-items: center;
#   justify-content: center;
#   padding: 0 8px;
#   text-align: center;
#   user-select: none;
# }
#
# .highlight__label strong,
# .highlight__label span.highlight__label__secondary-label {
#   display: block;
#   font-size: 11px;
#   color: #fff;
#   -webkit-font-smoothing: subpixel-antialiased;
#   letter-spacing: 0.1em;
# }
#
# .highlight__label strong {
#   text-transform: uppercase;
# }
#
# .highlight__label span.highlight__label__secondary-label {
#   opacity: .75;
#   padding-left: 6px;
# }
#
# .highlight__content {
#   flex-wrap: wrap;
#   align-items: center;
#   padding: 2px 2px 2px 6px;
# }
#
#
# .highlight-container.highlight-container--bottom-labels .highlight.bottom {
#   margin-top: 6px;
# }
#
# .highlight.bottom {
#   display: block;
#   white-space: normal;
# }
#
# .highlight.bottom .highlight__content:after {
#   content: " ";
#   padding-right: 3px;
# }
#
# .highlight.bottom .highlight__label {
#   line-height: 14px;
#   padding-top: 1px;
# }
#
#
# .highlight.top {
#   flex-direction: column;
#   white-space: normal;
# }
#
# .highlight.top .highlight__label {
#   min-height: 22px;
# }
#
#
# .highlight.active,
# .highlight.active span {
#   color: #fff;
# }
#
# .highlight.active .highlight:not(.active) span {
#   color: #232323;
# }
#
# .highlight.clickable {
#   cursor: pointer;
# }
#
# .highlight.clickable.clickable.selected {
#   cursor: default;
# }
#
# .highlight.clickable.clicking {
#   opacity: 0.66;
#   transition-duration: 0s;
# }
#
# .clicking .highlight,
# .clicking .highlight span,
# .clicking .highlight:before,
# .clicking .highlight:after {
#   transition-duration: 0s;
# }
#
#
# .highlight.gray {
#   background: #f2f4f6;
# }
#
# .highlight.gray,
# .highlight-arrow--gray .highlight-arrow__triangle {
#   border-color: #a0aab5;
# }
#
# .highlight.gray .highlight__label,
# .highlight-arrow--gray .highlight-arrow__stalk,
# .highlight.gray .highlight__button .highlight__button__body {
#   background-color: #a0aab5;
# }
#
# .highlight.gray.active {
#   background: #a0aab5;
# }
#
# .highlight.gray.active .highlight__label {
#   background-color: #aab3bd;
# }
#
# .highlight.gray .highlight__button svg {
#   fill: #a0aab5;
# }
#
#
#
# .highlight.blue {
#   background: #edf4fa;
# }
#
# .highlight.blue,
# .highlight-arrow--blue .highlight-arrow__triangle {
#   border-color: #4db1f7;
# }
#
# .highlight.blue > .highlight__label,
# .highlight-arrow--blue .highlight-arrow__stalk,
# .highlight.blue .highlight__button .highlight__button__body {
#   background-color: #4db1f7;
# }
#
# .highlight.blue.active {
#   background: #4db1f7;
# }
#
# .highlight.blue.active > .highlight__label {
#   background-color: #5fb9f8;
# }
#
# .highlight.blue .highlight__button svg {
#   fill: #4db1f7;
# }
#
#
# .highlight.green {
#   background: #f1f4f1;
# }
#
# .highlight.green,
# .highlight-arrow--green .highlight-arrow__triangle {
#   border-color: #90ac4e;
# }
#
# .highlight.green > .highlight__label,
# .highlight-arrow--green .highlight-arrow__stalk,
# .highlight.green .highlight__button .highlight__button__body {
#   background-color: #90ac4e;
# }
#
# .highlight.green.active {
#   background: #90ac4e;
# }
#
# .highlight.green.active > .highlight__label {
#   background-color: #9bb460;
# }
#
# .highlight.green .highlight__button svg {
#   fill: #90ac4e;
# }
#
#
# .highlight.pink {
#   background: #f4f1f4;
# }
#
# .highlight.pink,
# .highlight-arrow--pink .highlight-arrow__triangle {
#   border-color: #ce6587;
# }
#
# .highlight.pink > .highlight__label,
# .highlight-arrow--pink .highlight-arrow__stalk,
# .highlight.pink .highlight__button .highlight__button__body {
#   background-color: #ce6587;
# }
#
# .highlight.pink.active {
#   background: #ce6587;
# }
#
# .highlight.pink.active > .highlight__label {
#   background-color: #d37593;
# }
#
# .highlight.pink .highlight__button svg {
#   fill: #ce6587;
# }
#
#
# .highlight.orange {
#   background: #f2f4f4;
# }
#
# .highlight.orange,
# .highlight-arrow--orange .highlight-arrow__triangle {
#   border-color: #dd9e3e;
# }
#
# .highlight.orange > .highlight__label,
# .highlight-arrow--orange .highlight-arrow__stalk,
# .highlight.orange .highlight__button .highlight__button__body {
#   background-color: #dd9e3e;
# }
#
# .highlight.orange.active {
#   background: #dd9e3e;
# }
#
# .highlight.orange.active > .highlight__label {
#   background-color: #e0a852;
# }
#
# .highlight.orange .highlight__button svg {
#   fill: #dd9e3e;
# }
#
#
# .highlight.purple {
#   background: #f1f0f7;
# }
#
# .highlight.purple,
# .highlight-arrow--purple .highlight-arrow__triangle {
#   border-color: #9a5eba;
# }
#
# .highlight.purple > .highlight__label,
# .highlight-arrow--purple .highlight-arrow__stalk,
# .highlight.purple .highlight__button .highlight__button__body {
#   background-color: #9a5eba;
# }
#
# .highlight.purple.active {
#   background: #9a5eba;
# }
#
# .highlight.purple.active > .highlight__label {
#   background-color: #a46ec1;
# }
#
# .highlight.purple .highlight__button svg {
#   fill: #9a5eba;
# }
#
#
# .highlight.teal {
#   background: #eef4f6;
# }
#
# .highlight.teal,
# .highlight-arrow--teal .highlight-arrow__triangle {
#   border-color: #5bb1ad;
# }
#
# .highlight.teal > .highlight__label,
# .highlight-arrow--teal .highlight-arrow__stalk,
# .highlight.teal .highlight__button .highlight__button__body {
#   background-color: #5bb1ad;
# }
#
# .highlight.teal.active {
#   background: #5bb1ad;
# }
#
# .highlight.teal.active > .highlight__label {
#   background-color: #6cb9b5;
# }
#
# .highlight.teal .highlight__button svg {
#   fill: #5bb1ad;
# }
#
#
# .highlight.tan {
#   background: #f2f4f4;
# }
#
# .highlight.tan,
# .highlight-arrow--tan .highlight-arrow__triangle {
#   border-color: #b0a481;
# }
#
# .highlight.tan > .highlight__label,
# .highlight-arrow--tan .highlight-arrow__stalk,
# .highlight.tan .highlight__button .highlight__button__body {
#   background-color: #b0a481;
# }
#
# .highlight.tan.active {
#   background: #b0a481;
# }
#
# .highlight.tan.active > .highlight__label {
#   background-color: #b8ad8e;
# }
#
# .highlight.tan .highlight__button svg {
#   fill: #b0a481;
# }
#
#
# .highlight.red {
#   background: #f5eef0;
# }
#
# .highlight.red,
# .highlight-arrow--red .highlight-arrow__triangle {
#   border-color: #df3838;
# }
#
# .highlight.red > .highlight__label,
# .highlight-arrow--red .highlight-arrow__stalk,
# .highlight.red .highlight__button .highlight__button__body {
#   background-color: #df3838;
# }
#
# .highlight.red.active {
#   background: #df3838;
# }
#
# .highlight.red.active > .highlight__label {
#   background-color: #e24c4c;
# }
#
# .highlight.red .highlight__button svg {
#   fill: #df3838;
# }
#
#
# .highlight.cobalt {
#   background: #eef0f5;
# }
#
# .highlight.cobalt,
# .highlight-arrow--cobalt .highlight-arrow__triangle {
#   border-color: #5f5b97;
# }
#
# .highlight.cobalt > .highlight__label,
# .highlight-arrow--cobalt .highlight-arrow__stalk,
# .highlight.cobalt .highlight__button .highlight__button__body {
#   background-color: #5f5b97;
# }
#
# .highlight.cobalt.active {
#   background: #5f5b97;
# }
#
# .highlight.cobalt.active > .highlight__label {
#   background-color: #6f6ca2;
# }
#
# .highlight.cobalt .highlight__button svg {
#   fill: #5f5b97;
# }
#
#
# .highlight.brown {
#   background: #f2f4f6;
# }
#
# .highlight.brown,
# .highlight-arrow--brown .highlight-arrow__triangle {
#   border-color: #6a4e3d;
# }
#
# .highlight.brown > .highlight__label,
# .highlight-arrow--brown .highlight-arrow__stalk,
# .highlight.brown .highlight__button .highlight__button__body {
#   background-color: #6a4e3d;
# }
#
# .highlight.brown.active {
#   background: #6a4e3d;
# }
#
# .highlight.brown.active > .highlight__label {
#   background-color: #796051;
# }
#
# .highlight.brown .highlight__button svg {
#   fill: #6a4e3d;
# }
#
#
# .highlight.slate {
#   background: #eceff1;
# }
#
# .highlight.slate,
# .highlight-arrow--slate .highlight-arrow__triangle {
#   border-color: #3b4247;
# }
#
# .highlight.slate > .highlight__label,
# .highlight-arrow--slate .highlight-arrow__stalk,
# .highligh
# <script>
#
# function handleHighlightMouseOver(el) {
#     $('[id='+el.getAttribute('id')+']').addClass('active');
#   }
#
# function handleHighlightMouseOut(el) {
#     $('[id='+el.getAttribute('id')+']').removeClass('active');
# }
#
# </script>

# %%
import sys
sys.path.append("../")
from span_identification.dataset import load_data

# %% [markdown]
# # Span Identification

# %%
def load_result(file):
    result = {}
    with open(file, "r") as f:
        for line in f:
            article_id, spl, spr = line.split('\t')
            result.setdefault(article_id, [])
            result[article_id].append([int(spl), int(spr)])
    return result


def show_result(result, articles_id, articles_content, task):
    articles_contents = dict(zip(articles_id, articles_content))
    for article_id in sorted(result):
        text = articles_contents[article_id]
        nlp_text = nlp(text)
        tokens_idx = np.array([token.idx for token in nlp_text])
        tokens = [token.text for token in nlp_text]
        
        spans = []
        for sp in result[article_id]:
            sp = list(sp)
            sp[0] = np.where(tokens_idx >= sp[0])[0][0]
            sp[1] = np.where(tokens_idx < sp[1])[0][-1]
            spans.append([sp[0], sp[1]])
        
        if len(spans) != 0:
            print(colored(article_id, 'red'))
            visualization.render(tokens, [spans], task=task)

# %%
articles_content, articles_id, _ = load_data('../datasets/dev-articles', 
                                             '../tools/data/russian_corpus_techniques.txt')
result = load_result('../results/SI_output_dev.txt')
show_result(result, articles_id, articles_content, 'SI')
# Out:
# 103
# <div style="padding: 16px;"><span>Почему </span><span>нет </span><span>паники </span><span>по </span><span>действительно </span><span>опасным </span><span>заболеваниям </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>ПМЗ </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YExyWq9Bo2ZBiLA7 </span><span>( </span><span>30.03.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Если </span><span>вы </span><span>это </span><span key=24 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>читаете </span> <span>, </span> <span>значит </span> <span>вам </span> <span>повезло </span> <span>не </span> <span>попасть </span> <span>почти </span> <span>в </span> <span>1,5 </span> <span>% </span> <span>россиян </span> <span>умерших </span> <span>в </span> <span>2020 </span> <span>году </span> <span>. </span> <span>Вы </span> <span>оказались </span> <span>счастливее </span> <span>2,1 </span> <span>млн </span> <span>человек </span> <span>. </span> <span>На </span> <span>этом </span> <span>хорошие </span> <span>новости </span> <span>заканчиваются </span> <span>. </span> <span>А </span> <span>теперь </span> <span>поговорим </span> <span>о </span> <span>по </span> <span>настоящему </span> <span>страшных </span> <span>болезнях </span> <span>, </span> <span>уносящих </span> <span>без </span> <span>малого </span> <span>1,5 </span> <span>млн </span> <span>жизней </span> <span>в </span> <span>России </span> <span>ежегодно </span></span></span><span>. </span><span>
#
#
#
#  </span><span>В </span><span>доковидные </span><span>годы </span><span>в </span><span>России </span><span>умирали </span><span>около </span><span>1 </span><span>800 </span><span>000 </span><span>человек </span><span>каждый </span><span>год </span><span>. </span><span>В </span><span>2020 </span><span>ковид </span><span>принес </span><span>дополнительных </span><span>160 </span><span>000 </span><span>смертей </span><span>, </span><span>если </span><span>верить </span><span>росстату </span><span>. </span><span>Примерно </span><span>столько </span><span>же </span><span>людей </span><span>умерли </span><span>из </span><span>- </span><span>за </span><span>методов </span><span>борьбы </span><span>с </span><span>ковидом </span><span>. </span><span>
#
#  </span><span>Я </span><span key=69 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>понимаю </span> <span>, </span> <span>что </span> <span>весь </span> <span>мир </span> <span>напуган </span> <span>страшным </span> <span>ковидом </span> <span>, </span> <span>от </span> <span>которого </span> <span>" </span> <span>люди </span> <span>падают </span> <span>замертво </span> <span>" </span> <span>, </span> <span>в </span> <span>" </span> <span>красной </span> <span>зоне </span> <span>" </span> <span>цепляются </span> <span>за </span> <span>жизнь </span> <span>и </span> <span>вообще </span> <span>всем </span> <span>ковид </span> <span>- </span> <span>диссидентам </span> <span>надо </span> <span>там </span> <span>побывать </span> <span>. </span> <span>К </span> <span>ежедневной </span> <span>статистике </span> <span>смертей </span> <span>во </span> <span>всем </span> <span>мире </span> <span>прибавляется </span> <span>по </span> <span>  </span> <span>несколько </span> <span>тысяч </span> <span>человек </span> <span>, </span> <span>умирающих </span> <span>от </span> <span>коронавируса </span></span></span><span>. </span><span>  </span><span>Это </span><span>не </span><span>мало </span><span>, </span><span>но </span><span>почему </span><span>- </span><span>то </span><span>подобной </span><span>паники </span><span>больше </span><span>не </span><span>вызывает </span><span>ни </span><span>одно </span><span>заболевание </span><span>и </span><span>ни </span><span>одна </span><span>другая </span><span>смерть </span><span>, </span><span>коих </span><span>гораздо </span><span>больше </span><span>
#
#  </span><span>Вернемся </span><span>в </span><span>грешную </span><span>Россию </span><span>, </span><span>ведь </span><span>в </span><span>этой </span><span>стране </span><span>я </span><span>живу </span><span>, </span><span>и </span><span>слежу </span><span>за </span><span>событиями </span><span>куда </span><span>более </span><span>внимательно </span><span>, </span><span>чем </span><span>за </span><span>всем </span><span>миром </span><span>. </span><span>
#
#  </span><span>Давайте </span><span>сравнивать </span><span>
#
#  </span><span>За </span><span>2020 </span><span>год </span><span>ковид </span><span>унес </span><span>примерно </span><span>70 </span><span>000 </span><span>жизней </span><span>( </span><span>по </span><span>данным </span><span>статистики </span><span>яндекса </span><span>) </span><span>и </span><span>около </span><span>160 </span><span>000 </span><span>жизней </span><span>по </span><span>данным </span><span>Росстат </span><span>( </span><span>такие </span><span>же </span><span>данные </span><span>озвучивают </span><span>и </span><span>другие </span><span>официальные </span><span>источники </span><span>) </span><span>. </span><span>При </span><span>этом </span><span>молчит </span><span>Росстат </span><span>о </span><span>более </span><span>чем </span><span>1 </span><span>млн </span><span>смертей </span><span>от </span><span>сердечно </span><span>сосудистых </span><span>заболеваний </span><span>в </span><span>2020 </span><span>году </span><span>и </span><span>более </span><span>чем </span><span>300 </span><span>000 </span><span>случаев </span><span>смертей </span><span>от </span><span>онкологии </span><span>в </span><span>России </span><span>. </span><span>То </span><span>есть </span><span>ССЗ </span><span>и </span><span>Рак </span><span>становились </span><span>причинами </span><span>смертей </span><span>в </span><span>10 </span><span>раз </span><span>чаще </span><span>чем </span><span>ковид </span><span>. </span><span>
#
#  </span><span key=206 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Для </span> <span>сравнения </span> <span>, </span> <span>смертность </span></span></span><span>: </span><span>
#
#  </span><span>от </span><span>ССЗ </span><span>в </span><span>2020 </span><span>году </span><span>умирал </span><span>710 </span><span>человек </span><span>и </span><span>100 </span><span>000 </span><span>россиян </span><span>
#
#  </span><span>от </span><span>рака </span><span>в </span><span>России </span><span>умирали </span><span>250 </span><span>человек </span><span>из </span><span>100 </span><span>000 </span><span>граждан </span><span>
#
#  </span><span>от </span><span>ковида </span><span>в </span><span>2020 </span><span>году </span><span>100 </span><span>на </span><span>100 </span><span>000 </span><span>человек </span><span>
#
#  </span><span>Изученность </span><span>болезни </span><span>: </span><span>
#
#  </span><span key=249 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ковид-19 </span> <span>новое </span> <span>заболевание </span> <span>, </span> <span>вызываемое </span> <span>одним </span> <span>из </span> <span>видов </span> <span>коронавируса </span> <s
# 110
# <div style="padding: 16px;"><span>ЛЖЕ </span><span>- </span><span>ПАНДЕМИЯ </span><span>КОРОНАВИРУСА </span><span>- </span><span>ВСЕМИРНАЯ </span><span>АФЁРА </span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ВИДЕО </span><span>: </span><span>ВАКЦИННЫЙ </span><span>НАНО </span><span>- </span><span>БИОЧИП </span><span>ВСЕХ </span><span>СПАСЁТ </span><span>. </span><span>нано </span><span>- </span><span>биочип </span><span>под </span><span>видом </span><span>вакцины </span><span>. </span><span>интервью </span><span>билла </span><span>гейтса </span><span>от </span><span>4.11.2021 </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>27 </span><span>мая </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_437%2Fall </span><span>) </span><span>
#
#  </span><span>ВИДЕО </span><span>: </span><span key=46 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ВАКЦИННЫЙ </span> <span>НАНО </span> <span>- </span> <span>БИОЧИП </span> <span>ВСЕХ </span> <span>СПАСЁТ </span> <span>. </span> <span>нано </span> <span>- </span> <span>биочип </span> <span>под </span> <span>видом </span> <span>вакцины </span> <span>. </span> <span>интервью </span> <span>билла </span> <span>гейтса </span> <span>от </span> <span>4.11.2021 </span> <span>. </span> <span>КОВИД </span> <span>- </span> <span>ФАШИСТ </span> <span>БИЛЛ </span> <span>ГЕЙТС </span> <span>СКАЗАЛ </span> <span>ПОЧТИ </span> <span>СЛЕДУЮЩЕЕ </span> <span>: </span> <span>БУРАТИНЫ </span> <span>ПЛАНЕТЫ </span> <span>ДУРАКОВ </span> <span>! </span> <span>НАНО </span> <span>- </span> <span>БИОЧИПЫ </span> <span>, </span> <span>КОТОРЫЕ </span> <span>МЫ </span> <span>ОБМАНОМ </span> <span>ВСТАВЛЯЕМ </span> <span>ВАМ </span> <span>ПОД </span> <span>ВИДОМ </span> <span>ВАКЦИН </span> <span>, </span> <span>ЭТО </span> <span>ОЧЕНЬ </span> <span>КРУТО </span> <span>И </span> <span>ЗДОРОВО </span> <span>! </span> <span>ВИРУСЫ </span> <span>БУДУТ </span> <span>ОТСКАКИВАТЬ </span> <span>ОТ </span> <span>ВАКЦИННОГО </span> <span>НАНО </span> <span>- </span> <span>БИОЧИПА </span> <span>, </span> <span>КАК </span> <span>МЯЧИКИ </span> <span>ОТ </span> <span>СТЕНКИ </span></span></span><span>. </span><span>
#
#
#
#  </span><span>( </span><span key=50 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>неизвестно </span> <span>кто </span> <span>это </span> <span>- </span> <span>оригинал </span> <span>, </span> <span>двойник </span> <span>, </span> <span>клон </span> <span>, </span> <span>цифрововой </span> <span>аватар </span> <span>от </span> <span>ИИ </span> <span>, </span> <span>сделанный </span> <span>с </span> <span>помощью </span> <span>технологии </span> <span>видео </span> <span>- </span> <span>монтажа </span> <span>и </span> <span>обмана </span> <span>Deep </span> <span>Fake </span> <span>или </span> <span>старое </span> <span>интервью </span> <span>, </span> <span>выданное </span> <span>за </span> <span>новое </span></span></span><span>) </span><span>. </span><span>
#
#  </span><span>так </span><span>как </span><span>мы </span><span>знаём </span><span>, </span><span>что </span><span>билл </span><span>гейтс </span><span>был </span><span>казнён </span><span>1.10.2021 </span><span>. </span><span>см. </span><span>ГУАНТАНАМО </span><span>. </span><span>ОГНЕННАЯ </span><span>ЗЕМЛЯ </span><span>. </span><span>хроника </span><span>спецопераций </span><span>, </span><span>арестов </span><span>и </span><span>трибуналов </span><span>над </span><span>ковид </span><span>- </span><span>фашистами </span><span>. </span><span>
#
#  </span><span key=84 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>СПРАВКА </span> <span>: </span> <span>- </span> <span>поскольку </span> <span>уже </span> <span>множество </span> <span>независимых </span> <span>учёных </span> <span>из </span> <span>разных </span> <span>стран </span> <span>провели </span> <span>научные </span> <span>исследования </span> <span>по </span> <span>ГМО </span> <span>- </span> <span>вакцинам </span> <span>, </span> <span>то </span> <span>скрывать </span> <span>и </span> <span>дальше </span> <span>уже </span> <span>нет </span> <span>смысла </span> <span>. </span> <span>мировое </span> <span>правительство </span> <span>через </span> <span>билла </span> <span>гейтса </span> <span>подтвердило </span> <span>, </span> <span>что </span> <span>их </span> <span>ГМО </span> <span>- </span> <span>вакцины </span> <span>вовсе </span> <span>не </span> <span>вакцины </span> <span>, </span> <span>а </span> <span>чипы </span> <span>, </span> <span>или </span> <span>если </span> <span>точнее </span> <span>, </span> <span>то </span> <span>нано </span> <span>- </span> <span>биочипы </span> <span>. </span> <span>биочипы </span> <span>состоят </span> <span>из </span> <span>нано </span> <span>- </span> <span>частиц </span> <span>, </span> <span>например </span> <span>из </span> <span>оксида </span> <span>графена </span> <span>. </span> <span>оксид </span> <span>графена </span> <span>самовоспроизводится </span> <span>в </span> <span>нано </span> <span>- </span> <span>структуры </span> <span>, </span> <span>в </span> <span>нано </span> <span>- </span> <span>блоки </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>оксид </span><span>графена </span><span>создаёт </span><span>надстройку </span><span>в </span><span>организме </span><span>человека </span><span>, </span><span>сходную </span><span>по </span><span>аналогии </span><span>с </span><span>операционной </span><span>системой </span><span>майкрософт </span><span>. </span><span>оксид </span><span>графена </span><span>, </span><span>попадая </span><span>в </span><span>организм </span><span>человека </span><span>, </span><span>растёт </span><span>питаясь </span><span>за </span><span>счёт </span><span>окружающей </span><span>структуры </span><span>организма </span><span>человека </span><span>. </span><span>
#
#  </span><span>- </span><span>в </span><span>вакцинном </span><span>нано </span><span>- </span><span>биочипе </span><span>, </span><span>заложены </span><span>механизмы </span><span>изменения </span><span>генома </span><span>- </span><span>ДНК </span><span>человека </span><span>. </span><span>то </span><span>есть </span><span>присутствуют </span><span>нано </span><span>- </span><span>инструменты </span><span>- </span><span>генетические </span><span>ножницы </span><span>и </span><span>нано </span><span>- </span><span>технология </span><span>КРИСПР </span><span>. </span><span>
#
#
#
#  </span><span>- </span><span>почему </span><span>био </span><span>? </span><span>потому </span><span>что </span><span>так </span><span>оно </span><span>и </span><span>есть </span><span>: </span><span>
#
#  </span><span>1 </span><span>) </span><span>поскольку </span><span>оксид </span><span>графена </span><span>биосовместим </span><span>с </span><span>организмом </span><span>человека </span><span>хотя </span><span>и </span><span>высокотоксичен </span><span>. </span><span>см. </span><span>ГРАФЕН </span><span>оксид </span><span>( </span><span>нано </span><span>- </span><span>чип </span><span>) </span><span>2 </span><span>) </span><span>структуры </span><span>нано </span><span>- </span><span>биочипа </span><span>созданы </span><span>так </span><span>, </span><s
# 111
# <div style="padding: 16px;"><span>Еще </span><span>новости </span><span>последнего </span><span>времени </span><span>- </span><span>ковид </span><span>- </span><span>паспорта </span><span>и </span><span>чипы </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Ключи </span><span>разумения </span><span>. </span><span>Апокалипсис </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YHWLxFuJH1EZy621 </span><span>( </span><span>14.04.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Уважаемый </span><span>читатель </span><span>, </span><span>мы </span><span>живем </span><span>в </span><span>такое </span><span>время </span><span>, </span><span>когда </span><span>новости </span><span>, </span><span>характеризующие </span><span>наступление </span><span>" </span><span>последнего </span><span>времени </span><span>" </span><span>- </span><span>времени </span><span>перед </span><span>установлением </span><span>власти </span><span>антихриста </span><span>и </span><span>затем </span><span>Вторым </span><span>пришествием </span><span>Христа </span><span>, </span><span>выходят </span><span>чуть </span><span>ли </span><span>не </span><span>каждый </span><span>день </span><span>, </span><span>даже </span><span>несколько </span><span>раз </span><span>в </span><span>день </span><span>. </span><span>
#
#  </span><span>Приходится </span><span>очень </span><span>хорошо </span><span>отсеивать </span><span>информацию </span><span>, </span><span>потому </span><span>что </span><span>много </span><span>публикуется </span><span>различных </span><span>фейков </span><span>. </span><span>
#
#  </span><span>Мне </span><span>кажется </span><span>, </span><span>что </span><span>на </span><span>это </span><span>и </span><span>расчет </span><span>- </span><span>публиковать </span><span>огромную </span><span>массу </span><span>фейков </span><span>и </span><span>вместе </span><span>с </span><span>тем </span><span>вполне </span><span>реальные </span><span>новости </span><span>, </span><span>чтобы </span><span>снизить </span><span>у </span><span>людей </span><span>уровень </span><span>критической </span><span>оценки </span><span>событий </span><span>. </span><span>
#
#  </span><span>О </span><span>признаках </span><span>приближающей </span><span>власти </span><span>антихриста </span><span>я </span><span>писал </span><span>в </span><span>этой </span><span>статье </span><span>" </span><span>Признаки </span><span>приближающейся </span><span>власти </span><span>Антихриста </span><span>" </span><span>, </span><span>анализируя </span><span>некоторые </span><span>мировые </span><span>тренды </span><span>. </span><span>
#
#  </span><span>Буквально </span><span>на </span><span>днях </span><span>прочитал </span><span>сразу </span><span>несколько </span><span>новостей </span><span>, </span><span>некоторые </span><span>оказались </span><span>фейковыми </span><span>. </span><span>Например </span><span>, </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>вакцинах </span><span>будет </span><span>чип </span><span>от </span><span>Microsoft </span><span>оказалась </span><span>фейком </span><span>англоязычного </span><span>сатирического </span><span>  </span><span>сайта </span><span>. </span><span>
#
#  </span><span>Но </span><span>вот </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span>ученые </span><span>Пентагона </span><span>разработали </span><span>микрочип </span><span>, </span><span>который </span><span>вводится </span><span>под </span><span>кожу </span><span>и </span><span>диагностирует </span><span>COVID-19 </span><span>, </span><span>и </span><span>этот </span><span>микрочип </span><span>реально </span><span>очень </span><span>маленький </span><span>- </span><span>вполне </span><span>реальна </span><span>. </span><span>Ее </span><span>опубликовали </span><span>такие </span><span>известные </span><span>издания </span><span>как </span><span>  </span><span>the </span><span>SUN </span><span>, </span><span>  </span><span>NYPost </span><span>, </span><span>  </span><span>Independent </span><span>  </span><span key=218 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>и </span> <span>другие </span></span></span><span>. </span><span>
#
#  </span><span>Будет </span><span>ли </span><span>этот </span><span>чип </span><span>начертанием </span><span>? </span><span>Нет </span><span>. </span><span>Но </span><span>все </span><span>это </span><span>звенья </span><span>в </span><span>одной </span><span>большой </span><span>цепочке </span><span>событий </span><span>, </span><span>как </span><span>и </span><span>другая </span><span>новость </span><span>их </span><span>этого </span><span>поста </span><span>. </span><span>
#
#  </span><span>Одновременно </span><span>с </span><span>этим </span><span>в </span><span>европейской </span><span>  </span><span>прессе </span><span>  </span><span>появляется </span><span>высказывание </span><span>Тьерри </span><span>Бретона </span><span>, </span><span>европейского </span><span>комиссара </span><span>, </span><span>возглавляющего </span><span>целевую </span><span>группу </span><span>ЕС </span><span>по </span><span>вакцинам </span><span>, </span><span>который </span><span>говорит </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>начале </span><span>лета </span><span>, </span><span>с </span><span>15 </span><span>июня </span><span>, </span><span>будет </span><span>запущен </span><span>общеевропейский </span><span>паспорт </span><span>здоровья </span><span>, </span><span>паспорт </span><span>вакцинации </span><span>, </span><span>который </span><span>будет </span><span>содержать </span><span>как </span><span>данные </span><span>о </span><span>мазках </span><span>тестирования </span><span>с </span><span>датами </span><span>и </span><span>результатами </span><span>, </span><span>так </span><span>и </span><span>с </span><span>информацией </span><span>о </span><span>вакцинировании </span><span>, </span><span>все </span><span>это </span><span>с </span><span>QR </span><span>кодами </span><span>. </span><span>Паспорт </span><span>позволит </span><span>путешествовать </span><span>и </span><span>давать </span><span>право </span><span>входа </span><span>в </span><span>публичные </span><span>места </span><span>. </span><span>
#
#  </span><span>Вот </span><span>такие </span><span>новости </span><span>всего </span><span>за </span><span>пару </span><span>дней </span><span>. </span><span>Признаки </span><span>ли </span><span>это </span><span>последнего </span><span>времени </span><span>? </span><span>Вероятно </span><span>да </span><span>. </span><span>
#
#  </span><span>Кстати </span><span>, </span><span>для </span><span>описания </span><span>слова </span><span>" </span><span>начертание </span><span>" </span><span>в </span><span>книге </span><span>Откровения </span><span>Иоанна </span><span>Богослова </span><span>используется </span><span>интересное </span><span>греческое </span><span>слово </span><span>- </span><span>  </span><span key=369 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>хАрагма </span> <span>- </span> <span>клеймо </span> <span>, </span> <span>а </span> <span>также </span> <span>это </span> <span>слово </span> <span>имеет </span> <span>и </span> <span>другие </span> <span>значения </span></span></span><span>: </span><span>
#
#  </span><span key=372 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlig
# 115
# <div style="padding: 16px;"><span>Ковид </span><span>стоит </span><span>триллиарды </span><span>долларов </span><span>. </span><span>Правда </span><span>, </span><span>от </span><span>которой </span><span>не </span><span>убежать </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Родина </span><span>Слонов </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YP5vrjuTmlH6WvYm </span><span>( </span><span>27.07.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Дочитайте </span><span>эту </span><span>статью </span><span>до </span><span>конца </span><span>- </span><span>и </span><span>вы </span><span>согласитесь </span><span>, </span><span>что </span><span>коронавирус </span><span>стал </span><span>очень </span><span>своевременным </span><span>и </span><span>очень </span><span>выгодным </span><span>решением </span><span>. </span><span>И </span><span>знаете </span><span>, </span><span>для </span><span>кого </span><span>конкретно </span><span>? </span><span>
#
#  </span><span>Чтобы </span><span key=55 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>объяснить </span> <span>, </span> <span>откуда </span> <span>автору </span> <span>пришло </span> <span>озарение </span> <span>на </span> <span>эту </span> <span>тему </span> <span>, </span> <span>нужно </span> <span>сообщить </span> <span>, </span> <span>что </span> <span>идёт </span> <span>пятый </span> <span>день </span> <span>моих </span> <span>мучений </span> <span>с </span> <span>этим </span> <span>заболеванием </span> <span>. </span> <span>На </span> <span>третий </span> <span>день </span> <span>сделал </span> <span>ПЦР </span> <span>- </span> <span>тест </span> <span>, </span> <span>на </span> <span>четвертый </span> <span>- </span> <span>тест </span> <span>вышел </span> <span>положительным </span> <span>. </span> <span>А </span> <span>ведь </span> <span>я </span> <span>так </span> <span>хорошо </span> <span>и </span> <span>удачно </span> <span>проскочил </span> <span>через </span> <span>первые </span> <span>две </span> <span>волны </span> <span>, </span> <span>что </span> <span>уже </span> <span>считал </span> <span>себя </span> <span>бессмертным </span> <span>и </span> <span>неуязвимым </span> <span>, </span> <span>как </span> <span>горец </span> <span>... </span> <span>Теперь </span> <span>— </span> <span>мучение </span> <span>- </span> <span>лечение </span> <span>, </span> <span>да </span> <span>ещё </span> <span>пришлось </span> <span>отказаться </span> <span>от </span> <span>экспедиции </span> <span>на </span> <span>Перевал </span> <span>Дятлова </span> <span>( </span> <span>а </span> <span>готовилась </span> <span>она </span> <span>полгода </span> <span>) </span> <span>, </span> <span>ну </span> <span>в </span> <span>- </span> <span>общем </span> <span>, </span> <span>расклад </span> <span>для </span> <span>старта </span> <span>мыслей </span> <span>был </span> <span>позитивный </span></span></span><span>... </span><span>
#
#  </span><span>Откуда </span><span>и </span><span>для </span><span>чего </span><span>могла </span><span>взяться </span><span>проклятая </span><span>ковидла </span><span>— </span><span>и </span><span>, </span><span>главное </span><span>, </span><span>когда </span><span>это </span><span>всё </span><span>нас </span><span>окончательно </span><span>минует </span><span>? </span><span>
#
#  </span><span>Помните </span><span>старый </span><span>анекдот </span><span>, </span><span>как </span><span>заработать </span><span>трём </span><span>программистам </span><span>? </span><span>Один </span><span>пишет </span><span>вирусы </span><span>, </span><span>второй </span><span>антивирусы </span><span>, </span><span>а </span><span>третий </span><span>- </span><span>программное </span><span>обеспечение </span><span>, </span><span>в </span><span>котором </span><span>всё </span><span>это </span><span>работает </span><span>. </span><span>
#
#  </span><span>Для </span><span key=109 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>тех </span> <span>, </span> <span>кто </span> <span>с </span> <span>ходу </span> <span>уже </span> <span>думает </span> <span>, </span> <span>что </span> <span>просёк </span> <span>нить </span> <span>разговора </span> <span>, </span> <span>можете </span> <span>сразу </span> <span>листнуть </span> <span>вниз </span> <span>, </span> <span>до </span> <span>комментариев </span> <span>, </span> <span>и </span> <span>там </span> <span>оставить </span> <span>отметку </span> <span>наподобие </span> <span>" </span> <span>Автор </span> <span>, </span> <span>браво </span> <span>, </span> <span>всё </span> <span>верняк </span> <span>, </span> <span>пиши </span> <span>исчо </span> <span>" </span> <span>или </span> <span>просто </span> <span>" </span> <span>Здесь </span> <span>был </span> <span>Вася </span> <span>" </span> <span>или </span> <span>даже </span> <span>" </span> <span>Как </span> <span>обычно </span> <span>, </span> <span>полная </span> <span>чушь </span> <span>" </span> <span>( </span> <span>последнее </span> <span>, </span> <span>правда </span> <span>, </span> <span>не </span> <span>столь </span> <span>эпично </span></span></span><span>) </span><span>. </span><span>
#
#  </span><span>А </span><span>тем </span><span>, </span><span>кто </span><span>решит </span><span>прочитать </span><span>полностью </span><span>- </span><span>вы </span><span>молодцы </span><span>, </span><span>я </span><span>заранее </span><span>вами </span><span>горжусь </span><span>, </span><span>пытливые </span><span>умы </span><span>. </span><span>
#
#
#
#  </span><span>Это </span><span key=134 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>была </span> <span>, </span> <span>конечно </span> <span>, </span> <span>шутка </span> <span>, </span> <span>от </span> <span>моего </span> <span>любимого </span> <span>юмористического </span> <span>журнала </span> <span>" </span> <span>Красная </span> <span>Бурда </span> <span>" </span> <span>. </span> <span>А </span> <span>вот </span> <span>что </span> <span>не </span> <span>является </span> <span>шуткой </span> <span>, </span> <span>так </span> <span>это </span> <span>факт </span> <span>, </span> <span>что </span></span></span><span>  </span><span>вирус </span><span>- </span><span>то </span><span>напоминает </span><span>боевой </span><span>. </span><span>Это </span><span>было </span><span>понятно </span><span>, </span><span>когда </span><span>выяснилась </span><span>его </span><span>особенность </span><span>в </span><span>виде </span><span>отключения </span><span>обоняния </span><span>( </span><span>или </span><span>" </span><span>нюха </span><span>" </span><span>, </span><span>как </span><span>любят </span><span>говорить </span><span>в </span><span>России </span><span>) </span><span>- </span><span>интересненький </span><span>эксперимент </span><span>по </span><span>лишению </span><span>человека </span><span>конкретной </span><span>функции </span><span>( </span><span>сегодня </span><span>- </span><span>нос </span><span>, </span><span>завтра </span><span>- </span><span>руку </span><span>можно </span><span>отстегнуть </span><span>? </span><span>) </span><span>, </span><span>но </span><span>стало </span><span>особенно </span><span>явно </span><span>, </span><span>когда </span><span>появились <
# 12
# <div style="padding: 16px;"><span>Кинология </span><span>для </span><span>каждого </span><span>. </span><span>Все </span><span>о </span><span>собаках </span><span>и </span><span>не </span><span>только </span><span>. </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>4 </span><span>января </span><span>( </span><span>) </span><span>
#
#
#
#  </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>. </span><span>Автор </span><span>Ирина </span><span>Видус </span><span>
#
#  </span><span>- </span><span>У </span><span>собачников </span><span>очень </span><span>сильный </span><span>иммунитет </span><span>, </span><span>ведь </span><span>они </span><span>рано </span><span>встают </span><span>и </span><span>ежедневно </span><span>гуляют </span><span>по </span><span>2 </span><span>- </span><span>3 </span><span>часа </span><span>в </span><span>любую </span><span>погоду </span><span>
#  </span><span>- </span><span>А </span><span>ещё </span><span>их </span><span>иммунитет </span><span>натренирован </span><span>, </span><span>ведь </span><span>он </span><span>каждый </span><span>день </span><span>сталкивается </span><span>с </span><span>кучей </span><span>бактерий </span><span>/ </span><span>вирусов </span><span>и </span><span>успешно </span><span>их </span><span>побеждает </span><span>. </span><span>
#  </span><span>- </span><span>У </span><span>собачника </span><span>крепкая </span><span>нервная </span><span>система </span><span>, </span><span>а </span><span>это </span><span>неплохой </span><span>щит </span><span>для </span><span>любой </span><span>инфекции </span><span>. </span><span>Собачник </span><span>каждый </span><span>день </span><span>противостоит </span><span>догхантерам </span><span>, </span><span>
#  </span><span>яжематерям </span><span>, </span><span>собаконенавистникам </span><span>и </span><span>не </span><span>теряет </span><span>бодрость </span><span>духа </span><span>и </span><span>оптимизм </span><span>. </span><span>Собачники </span><span>умеют </span><span>радоваться </span><span>каждому </span><span>пустяку </span><span>, </span><span>любить </span><span>природу </span><span>, </span><span>братьев </span><span>наших </span><span>меньших </span><span>. </span><span>Они </span><span>не </span><span>пойдут </span><span>скупать </span><span>гречку </span><span>и </span><span>туалетную </span><span>бумагу </span><span>. </span><span>Пожалуй </span><span>, </span><span>собачник </span><span>купит </span><span>новый </span><span>мячик </span><span>щенку </span><span>и </span><span>капли </span><span>с </span><span>ошейником </span><span>от </span><span>блох </span><span>и </span><span>клещей </span><span>для </span><span>взрослой </span><span>собаки </span><span>. </span><span>
#  </span><span>- </span><span>Собачники </span><span>живут </span><span>по </span><span>четкому </span><span>режиму </span><span>, </span><span>они </span><span>очень </span><span>рано </span><span>встают </span><span>, </span><span>выходят </span><span>гулять </span><span>с </span><span>собакой </span><span>в </span><span>одно </span><span>и </span><span>то </span><span>же </span><span>время </span><span>, </span><span>кормят </span><span>щенков </span><span>по </span><span>часам </span><span>. </span><span>Собачники </span><span>не </span><span>тусят </span><span>в </span><span>клубах </span><span>, </span><span>редко </span><span>проводят </span><span>время </span><span>в </span><span>ТЦ </span><span>, </span><span>не </span><span>жалуют </span><span>алкоголь </span><span>и </span><span>сигареты </span><span>, </span><span>потому </span><span>что </span><span>этот </span><span>запах </span><span>не </span><span>любят </span><span>их </span><span>хвостики </span><span>. </span><span>Обожают </span><span>поля </span><span>, </span><span>леса </span><span>, </span><span>походы </span><span>, </span><span>поездки </span><span>за </span><span>город </span><span>и </span><span>дачу </span><span>. </span><span>Могут </span><span>прилечь </span><span>днем </span><span>спать </span><span>вместе </span><span>с </span><span>любимыми </span><span>хвостиками </span><span>, </span><span>нагулявшись </span><span>в </span><span>лесу </span><span>. </span><span>Подобный </span><span>иммунный </span><span>щит </span><span>и </span><span>здоровый </span><span>образ </span><span>жизни </span><span>неплохо </span><span>противостоит </span><span>вирусам </span><span>. </span><span>
#  </span><span>- </span><span>Собачники </span><span>и </span><span>без </span><span>того </span><span>сидят </span><span>на </span><span>карантине </span><span>. </span><span>Сперва </span><span>исчезают </span><span>родственники </span><span>, </span><span>потом </span><span>" </span><span>друзья </span><span>" </span><span>, </span><span>затем </span><span>и </span><span>соседи </span><span>перестают </span><span>захаживать </span><span>. </span><span>Любимая </span><span>фраза </span><span>собачника:"чем </span><span>меньше </span><span>вокруг </span><span>народа </span><span>, </span><span>тем </span><span>лучше </span><span>для </span><span>моей </span><span>собаки </span><span>" </span><span>. </span><span>
#  </span><span>- </span><span>Собачник </span><span>смело </span><span>может </span><span>тереть </span><span>нос </span><span>и </span><span>глаза </span><span>рукой </span><span>. </span><span>Кожный </span><span>и </span><span>общий </span><span>иммунитет </span><span>собаковода </span><span>всегда </span><span>на </span><span>высоте </span><span>, </span><span>после </span><span>того </span><span>как </span><span>лицо </span><span>каждый </span><span>день </span><span>облизывает </span><span>любимая </span><span>собака </span><span>. </span><span>Тем </span><span>более </span><span>слюна </span><span>содержит </span><span>не </span><span>только </span><span>бактерии </span><span>, </span><span>но </span><span>и </span><span>лизоцим </span><span>, </span><span>повышающий </span><span>иммунитет </span><span>и </span><span>оказывающий </span><span>
#  </span><span>бактерицидное </span><span>действие </span><span>. </span><span>А </span><span>от </span><span>" </span><span>носоцелования </span><span>" </span><span>не </span><span>откажется </span><span>в </span><span>здравом </span><span>смысле </span><span>ни </span><span>один </span><span>владелец </span><span>пса </span><span>. </span><span>Так </span><span>же </span><span>многие </span><span>собачники </span><span>пускают </span><span>собак </span><span>в </span><span>постель </span><span>, </span><span>что </span><span>плавно </span><span>, </span><span>изо </span><span>дня </span><span>в </span><span>день </span><span>, </span><span>закаливает </span><span>их </span><span>иммунитет </span><span>. </span><span>А </span><span>ещё </span><span>собачники </span><span>лучше </span><span>высыпаются </span><span>с </span><span>питомцам </span><span>, </span><span>меньше </span><span>боятся </span><span>бытовых </span><span>проблем </span><span>и </span><span>реже </span><span>переживают </span><span>по </span><span>пустякам </span><span>. </span><span>
#  </span><span>- </span><span>Вирусы </span><span>и </span><span>бактерии </span><span>со </span><span>страхом </span><span>бегут </span><span>из </span><span>сумочки </span><span>собачника </span><span>, </span><span>прочь </span><span>от </span><span>его </span><span>гаджетов </span><span>и </span><span>телефона </span><span>. </span><span>Ведь </span><span>там </span><span>уже </span><span>живут </span><span>свои </span><span>матерые </span><span>бактерии </span><span>, </span><span>заселившиеся </span><span>после </span><span>залежалой </span><span>мумии </span><span>сосиски </span><span>, </span><span>заплесневелого </span><span>сыра </span><span>, </span><span>старого </span><span>корма </span><span>и
# 123
# <div style="padding: 16px;"><span>ЛЖЕ </span><span>- </span><span>ПАНДЕМИЯ </span><span>КОРОНАВИРУСА </span><span>- </span><span>ВСЕМИРНАЯ </span><span>АФЁРА </span><span>( </span><span>2022 </span><span>) </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span>Рикардо </span><span>Дельгадо </span><span>об </span><span>окончательном </span><span>заключении </span><span>экспертов </span><span>: </span><span>ВСЕ </span><span>СОВРЕМЕННЫЕ </span><span>" </span><span>ВАКЦИНЫ </span><span>" </span><span>СОДЕРЖАТ </span><span>ИСКЛЮЧИТЕЛЬНО </span><span>НАНО </span><span>- </span><span>ТЕХНОЛОГИИ </span><span>: </span><span>НАНО </span><span>- </span><span>РОУТЕРЫ </span><span>, </span><span>НАНО </span><span>- </span><span>РЕТЕННЫ </span><span>, </span><span>КОДЕКИ </span><span>, </span><span>НАНО </span><span>- </span><span>АНТЕННЫ </span><span>, </span><span>КОТОРЫЕ </span><span>ПЕРЕДАЮТ </span><span>МАК </span><span>- </span><span>АДРЕСА </span><span>НА </span><span>СЕРВЕР </span><span>ИИ </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>14 </span><span>апреля </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_415%2Fall </span><span>) </span><span>
#
#
#
#  </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span>Рикардо </span><span>Дельгадо </span><span>об </span><span>окончательном </span><span>заключении </span><span>экспертов </span><span>: </span><span>ВСЕ </span><span>СОВРЕМЕННЫЕ </span><span>" </span><span>ВАКЦИНЫ </span><span>" </span><span>СОДЕРЖАТ </span><span>ИСКЛЮЧИТЕЛЬНО </span><span>НАНО </span><span>- </span><span>ТЕХНОЛОГИИ </span><span>: </span><span>НАНО </span><span>- </span><span>РОУТЕРЫ </span><span>, </span><span>НАНО </span><span>- </span><span>РЕТЕННЫ </span><span>, </span><span>КОДЕКИ </span><span>, </span><span>НАНО </span><span>- </span><span>АНТЕННЫ </span><span>, </span><span>КОТОРЫЕ </span><span>ПЕРЕДАЮТ </span><span>МАК </span><span>- </span><span>АДРЕСА </span><span>НА </span><span>СЕРВЕР </span><span>ИИ </span><span>. </span><span>Что </span><span>содержат </span><span>" </span><span>вакцины </span><span>" </span><span>и </span><span>как </span><span>это </span><span>влияет </span><span>на </span><span>человека </span><span>. </span><span>доктор </span><span>рикардо </span><span>дельгадо </span><span>. </span><span>
#
#  </span><span>СОДЕРЖАНИЕ </span><span>ВИДЕО </span><span>: </span><span>
#
#  </span><span>- </span><span>0.05 </span><span>- </span><span>большой </span><span>группой </span><span>учёных </span><span>в </span><span>течение </span><span>нескольких </span><span>месяцев </span><span>было </span><span>протестировано </span><span>био </span><span>и </span><span>генное </span><span>оружие </span><span>под </span><span>названием </span><span>" </span><span>вакцины </span><span>" </span><span>от </span><span>коронавируса </span><span>- </span><span>пфайзер </span><span>, </span><span>джансен </span><span>, </span><span>модерна </span><span>, </span><span>астразенека </span><span>, </span><span>и </span><span>выяснилось </span><span>, </span><span>что </span><span>они </span><span>к </span><span>вакцинам </span><span>не </span><span>имеют </span><span>никакого </span><span>отношения </span><span>и </span><span>содержат </span><span>исключительно </span><span>нано </span><span>- </span><span>технологии </span><span>: </span><span>
#
#  </span><span>- </span><span key=198 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>нано </span> <span>- </span> <span>роутеры </span> <span>, </span> <span>которые </span> <span>передают </span> <span>МАК </span> <span>- </span> <span>адреса </span> <span>, </span> <span>и </span> <span>могут </span> <span>быть </span> <span>зарегистрированы </span> <span>в </span> <span>беспроводной </span> <span>технологии </span> <span>блютуф </span> <span>с </span> <span>помощью </span> <span>собственного </span> <span>мобильного </span> <span>телефона </span> <span>, </span> <span>и </span> <span>мобильного </span> <span>приложения </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span key=202 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>мы </span> <span>также </span> <span>нашли </span> <span>нано </span> <span>- </span> <span>антенны </span> <span>и </span> <span>плазмонные </span> <span>антенны </span> <span>для </span> <span>усиления </span> <span>этих </span> <span>сигналов </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>также </span><span>были </span><span>выявлены </span><span>нано </span><span>- </span><span>ретенны </span><span>, </span><span>которые </span><span>действуют </span><span>как </span><span>выпрямительные </span><span>мосты </span><span>постоянного </span><span>тока </span><span>, </span><span>кодеки </span><span>и </span><span>некоторые </span><span>логические </span><span>элементы </span><span>для </span><span>шифрования </span><span>этих </span><span>нано </span><span>- </span><span>коммуникаций </span><span>от </span><span>нано </span><span>- </span><span>привитого </span><span>человека </span><span>- </span><span>покемона </span><span>на </span><span>удалённый </span><span>сервер </span><span>. </span><span>
#
#  </span><span>- </span><span key=245 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>сырьём </span> <span>для </span> <span>разработки </span> <span>этих </span> <span>микроструктурных </span> <span>комплексов </span> <span>является </span> <span>оксид </span> <span>графена </span> <span>, </span> <span>наличие </span> <span>которого </span> <span>имеет </span> <span>решающее </span> <span>значение </span> <span>для </span> <span>самосборки </span> <span>указанных </span> <span>структурных </span> <span>комплексов </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>основными </span><span>механизмами </span><span>удаления </span><span>оксида </span><span>графена </span><span>из </span><span>организма </span><span>в </span><span>квантовых </span><span>точках </span><span>графена </span><span>являются </span><span>: </span><span>естественное </span><span>био </span><span>- </span><span>разложение </span><span>посредством </span><span>фермента </span><span>миелопероксидазы </span><span>и </span><span>механизм </span><span>теслафореза </span><span>, </span><span>который </span><span>представляет </span><span>собой </span><span>электромагнитные </span><span>поля </span><span>микроволнового </span><span>излучения </span><span>. </span><span>в </span><span>основном </span><span>исходящий </span><span>от </span><span>сигналов </span><span>мобильного </span><span>телефона </span><span>, </span><span>с </span><span>различными </span><span>частотными </span><span>качествами </span><span>. </span><span>
#
# ...
#
#
#
#  </span><span>- </span><span>главная </span><span>цель </span><span>, </span><span>главная </span><span>повестка </span><span>мирового </span><span>правительства </span><span>сатанистов </span><span>- </span><span>это </span><span>, </span><span>чтобы </span><span key=114 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>всем </span> <span>людям </span> <span>под </span> <span>видом </span> <span>их </span> <span>" </span> <span>спасения </span> <span>" </span> <span>и </span> <span>" </span> <span>безопасности </span> <span>, </span> <span>была </span> <span>установлена </span> <span>метка </span> <span>зверя </span> <span>, </span> <span>начертание </span> <span>, </span> <span>интерфейс </span> <span>мозг </span> <span>- </span> <span>компьютер </span> <span>, </span> <span>третья </span> <span>спираль </span> <span>ДНК </span> <span>, </span> <span>3-я </span> <span>спираль </span> <span>ДНК </span></span></span><span>. </span><span>
#
#
#
#
#
#  </span></div>
# 94
# <div style="padding: 16px;"><span>Всё </span><span>это </span><span>, </span><span>скорее </span><span>всего </span><span>, </span><span>вылезло </span><span>из </span><span>чьей </span><span>- </span><span>то </span><span>лаборатории </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Сергей </span><span>Михеев </span><span>; </span><span>URL </span><span>: </span><span>  </span><span>( </span><span>02.12.2022 </span><span>) </span><span>
#
#  </span><span>Первого </span><span>декабря </span><span>2019 </span><span>года </span><span>в </span><span>Ухане </span><span>был </span><span>зарегистрирован </span><span>первый </span><span>случай </span><span>пневмонии </span><span>неизвестной </span><span>этиологии </span><span>. </span><span>Это </span><span>произошло </span><span>три </span><span>года </span><span>назад </span><span>. </span><span>В </span><span>опубликованном </span><span>докладе </span><span>международного </span><span>союза </span><span>учёных </span><span>в </span><span>журнале </span><span>« </span><span>The </span><span>Lancet </span><span>» </span><span>говорится </span><span>, </span><span>что </span><span>одой </span><span>из </span><span>главнейших </span><span>версий </span><span>происхождения </span><span>COVID-19 </span><span>является </span><span>лабораторное </span><span>происхождение </span><span>. </span><span>
#
#  </span><span>По </span><span>поводу </span><span>журнала </span><span>« </span><span>The </span><span>Lancet </span><span>» </span><span>. </span><span>Я </span><span>ещё </span><span>тогда </span><span>говорил </span><span>о </span><span>том </span><span>, </span><span>что </span><span>происхождение </span><span>этого </span><span>вируса </span><span>крайне </span><span>подозрительное </span><span>. </span><span>Исключать </span><span>его </span><span>искусственное </span><span>происхождение </span><span>нельзя </span><span>. </span><span>Хотя </span><span>у </span><span>нас </span><span>многие </span><span>, </span><span>включая </span><span>и </span><span>наших </span><span>руководителей </span><span>, </span><span>говорили </span><span>, </span><span>что </span><span>это </span><span>маловероятно </span><span>. </span><span>И </span><span>вся </span><span>эта </span><span>шумиха </span><span>, </span><span>связанная </span><span>с </span><span>ним </span><span>, </span><span>явно </span><span>была </span><span>искусственно </span><span>подогреваема </span><span>. </span><span>Зачем </span><span>мы </span><span>к </span><span>ней </span><span>подключились </span><span>, </span><span>особенно </span><span>на </span><span>первом </span><span>этапе </span><span>, </span><span>для </span><span>меня </span><span>до </span><span>сих </span><span>пор </span><span>является </span><span>загадкой </span><span>. </span><span>
#
#  </span><span>Но </span><span>главное </span><span>сейчас </span><span>заключается </span><span>в </span><span>том </span><span>, </span><span>что </span><span>в </span><span>следующий </span><span>раз </span><span>надо </span><span>быть </span><span>умнее </span><span>. </span><span>Это </span><span>к </span><span>вопросу </span><span>о </span><span>том </span><span>: </span><span>« </span><span>Смотрите </span><span>, </span><span>все </span><span>побежали </span><span>, </span><span>и </span><span>мы </span><span>побежали </span><span>. </span><span>Европа </span><span>, </span><span>Америка </span><span>, </span><span>Китай </span><span>, </span><span>карантин </span><span>, </span><span>давай </span><span>всех </span><span>колоть </span><span>! </span><span>Давайте </span><span>и </span><span>мы </span><span>тоже </span><span>будем </span><span>всё </span><span>это </span><span>делать </span><span>! </span><span>» </span><span>. </span><span key=205 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>А </span> <span>в </span> <span>итоге </span> <span>, </span> <span>началась </span> <span>СВО </span> <span>, </span> <span>и </span> <span>вирус </span> <span>закончился </span> <span>сам </span> <span>собой </span></span></span><span>. </span><span>
#
#  </span><span key=208 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Это </span> <span>как </span> <span>шутили </span> <span>, </span> <span>что </span> <span>Владимир </span> <span>Путин </span> <span>одним </span> <span>росчерком </span> <span>пера </span> <span>завершил </span> <span>пандемию </span> <span>коронавируса </span> <span>. </span> <span>Это </span> <span>говорит </span> <span>о </span> <span>простой </span> <span>вещи </span> <span>: </span> <span>может </span> <span>быть </span> <span>, </span> <span>и </span> <span>не </span> <span>надо </span> <span>было </span> <span>такой </span> <span>бешеной </span> <span>паники </span> <span>развивать </span> <span>, </span> <span>людей </span> <span>так </span> <span>напрягать </span> <span>, </span> <span>нервировать </span> <span>? </span> <span>И </span> <span>не </span> <span>надо </span> <span>было </span> <span>повторять </span> <span>всё </span> <span>то </span> <span>, </span> <span>что </span> <span>было </span> <span>навязано </span> <span>Всемирной </span> <span>организацией </span> <span>здравоохранения </span> <span>и </span> <span>поддержано </span> <span>всеми </span> <span>этими </span> <span>глобалистскими </span> <span>элитами </span> <span>. </span> <span>На </span> <span>самом </span> <span>деле </span> <span>, </span> <span>всё </span> <span>то </span> <span>, </span> <span>что </span> <span>здесь </span> <span>происходило </span> <span>по </span> <span>ковиду </span> <span>, </span> <span>это </span> <span>была </span> <span>калька </span> <span>с </span> <span>западных </span> <span>практик </span> <span>, </span> <span>а </span> <span>так </span> <span>же </span> <span>прямое </span> <span>выполнение </span> <span>указаний </span> <span>глобалистских </span> <span>организаций </span> <span>здравоохранения </span> <span>. </span> <span>Это </span> <span>первое </span></span></span><span>. </span><span>
#
#  </span><span>Второе </span><span>даже </span><span>интереснее </span><span>. </span><span>Вот </span><span>это </span><span>мнение </span><span>учёных </span><span>, </span><span>которые </span><span>раньше </span><span>так </span><span>не </span><span>думали </span><span>, </span><span>а </span><span>сейчас </span><span>почему </span><span>- </span><span>то </span><span>стали </span><span>так </span><span>думать </span><span>, </span><span>говорит </span><span>о </span><span>том </span><span>, </span><span>что </span><span>всё </span><span>это </span><span>, </span><span>скорее </span><span>всего </span><span>, </span><span>вылезло </span><span>из </span><span>чьей </span><span>- </span><span>то </span><span>лаборатории </span><span>. </span><span>Вот </span><span>это </span><span>же </span><span>, </span><span>как </span><span>мне </span><span>кажется </span><span>, </span><span>самое </span><span>важное </span><span>. </span><span>Надо </span><span>всё </span><span>- </span><span>таки </span><span>выяснить </span><span>, </span><span>из </span><span>чьей </span><span>лаборатории </span><span>вылезло </span><span>. </span><span>Специально </span><span>, </span><span>или </span><span>случайно </span><span>. </span><span>Кто </span><span>способствовал </span><span>распространению </span><span>? </span><span>С </span><span>какой </span><span>целью </span><span>разрабатывалось </span><span>, </span><span>зачем </span><span>? </span><span>
#
#  </span
# 99
# <div style="padding: 16px;"><span>Преступления </span><span>ковид </span><span>- </span><span>фашистов </span><span>мирового </span><span>правит </span><span>- </span><span>ства </span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span>КОВИД </span><span>- </span><span>ФАШИСТА </span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span>НЕОФАШИСТОВ </span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span>НОВЫХ </span><span>ГИТЛЕРОВ </span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>29 </span><span>ноября </span><span>( </span><span>https://vk.com/public201975126?w=wall-201975126_973 </span><span>) </span><span>
#
#
#
#  </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span>КОВИД </span><span>- </span><span>ФАШИСТА </span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span>НЕОФАШИСТОВ </span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span>НОВЫХ </span><span>ГИТЛЕРОВ </span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>ВИДЕО </span><span>. </span><span>
#
#  </span><span>- </span><span>Школа </span><span>диктаторов </span><span>ковид </span><span>- </span><span>фашиста </span><span>Клауса </span><span>Шваба </span><span>( </span><span>ротшильда </span><span>) </span><span>, </span><span>или </span><span>план </span><span>великой </span><span>перезагрузки </span><span>. </span><span>9 </span><span>дек. </span><span>2021 </span><span>г. </span><span>
#
#  </span><span>- </span><span>новые </span><span>гитлеры </span><span>готовятся </span><span>в </span><span>ВЭФ </span><span>для </span><span>проведения </span><span>всемирных </span><span>спецопераций </span><span>: </span><span>
#
#  </span><span key=106 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>лже-"вакцинация </span> <span>" </span> <span>, </span> <span>лже </span> <span>- </span> <span>ПЦР </span> <span>- </span> <span>тестизация </span> <span>, </span> <span>QR </span> <span>- </span> <span>кодизация </span> <span>, </span> <span>цифровизация </span> <span>, </span> <span>зомби- </span> <span>и </span> <span>НЛП </span> <span>- </span> <span>пропаганда </span> <span>существования </span> <span>пандемий </span> <span>, </span> <span>штаммов </span> <span>, </span> <span>вирусов </span> <span>, </span> <span>которые </span> <span>на </span> <span>самом </span> <span>деле </span> <span>не </span> <span>существуют </span> <span>, </span> <span>спонсирование </span> <span>на </span> <span>частном </span> <span>и </span> <span>государственном </span> <span>уровне </span> <span>лже </span> <span>- </span> <span>учёных </span> <span>, </span> <span>которые </span> <span>скрывают </span> <span>, </span> <span>что </span> <span>нано </span> <span>- </span> <span>частицы </span> <span>, </span> <span>нано </span> <span>- </span> <span>технологии </span> <span>и </span> <span>5 </span> <span>джи </span> <span>- </span> <span>смертоносны </span> <span>и </span> <span>вредны </span> <span>для </span> <span>здоровья </span> <span>и </span> <span>иммунной </span> <span>системы </span> <span>человека </span></span></span><span>. </span><span>
#
#
#
#  </span><span>- </span><span key=110 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Одна </span> <span>из </span> <span>целей </span> <span>нынешней </span> <span>политики </span> <span>мирового </span> <span>правительства </span> <span>, </span> <span>проводимой </span> <span>правительствами </span> <span>многих </span> <span>стран </span> <span>, </span> <span>состоит </span> <span>в </span> <span>том </span> <span>, </span> <span>чтобы </span> <span>разрушить </span> <span>бизнес </span> <span>малых </span> <span>и </span> <span>средних </span> <span>предпринимателей </span> <span>. </span> <span>Чтобы </span> <span>транснациональные </span> <span>корпорации </span> <span>- </span> <span>ТНК </span> <span>, </span> <span>базирующиеся </span> <span>в </span> <span>Соединенных </span> <span>Штатах </span> <span>и </span> <span>Китае </span> <span>, </span> <span>смогли </span> <span>монополизировать </span> <span>бизнес </span> <span>повсюду </span> <span>и </span> <span>превратить </span> <span>народный </span> <span>капитализм </span> <span>в </span> <span>рабовладельческий </span> <span>строй </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>друзья </span><span>, </span><span>вы </span><span>наверное </span><span>совсем </span><span>чокнулись </span><span>, </span><span>если </span><span>ничего </span><span>не </span><span>делаете </span><span>для </span><span>того </span><span>, </span><span>чтобы </span><span>эту </span><span>ковид </span><span>- </span><span>фашистскую </span><span>сволочь </span><span>посадить </span><span>на </span><span>скамью </span><span>подсудимых </span><span>на </span><span>новом </span><span>нюрнбергском </span><span>трибунале </span><span>. </span><span>когда </span><span>они </span><span>и </span><span>наличные </span><span>деньги </span><span>отменят </span><span>, </span><span>вы </span><span>тоже </span><span>это </span><span>примите </span><span>? </span><span>отмена </span><span>денег </span><span>- </span><span>это </span><span>цель </span><span>коммунистов </span><span>, </span><span>а </span><span>не </span><span>капиталистов </span><span>. </span><span>
#
#  </span><span>- </span><span>где </span><span>работа </span><span>по </span><span>созданию </span><span>комитетов </span><span>избирателей </span><span>для </span><span>отзыва </span><span>депутатов </span><span>и </span><span>властей </span><span>? </span><span>где </span><span>митинги </span><span>и </span><span>демонстрации </span><span>? </span><span>где </span><span>борьба </span><span>? </span><span>да </span><span>, </span><span>есть </span><span>борцы </span><span>, </span><span>но </span><span>их </span><span>мало </span><span>. </span></div>

# %%
articles_content, articles_id, _ = load_data('../datasets/dev-articles', 
                                             '../tools/data/russian_corpus_techniques.txt')
result = load_result('../results/dev-task-SI.labels')
show_result(result, articles_id, articles_content, 'SI')
# Out:
# 103
# <div style="padding: 16px;"><span>Почему </span><span>нет </span><span>паники </span><span>по </span><span>действительно </span><span>опасным </span><span>заболеваниям </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>ПМЗ </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YExyWq9Bo2ZBiLA7 </span><span>( </span><span>30.03.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Если </span><span>вы </span><span>это </span><span>читаете </span><span>, </span><span>значит </span><span>вам </span><span>повезло </span><span>не </span><span>попасть </span><span>почти </span><span>в </span><span>1,5 </span><span>% </span><span>россиян </span><span>умерших </span><span>в </span><span>2020 </span><span>году </span><span>. </span><span>Вы </span><span>оказались </span><span>счастливее </span><span>2,1 </span><span>млн </span><span>человек </span><span>. </span><span key=48 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>На </span> <span>этом </span> <span>хорошие </span> <span>новости </span> <span>заканчиваются </span></span></span><span>. </span><span key=50 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>А </span> <span>теперь </span> <span>поговорим </span> <span>о </span> <span>по </span> <span>настоящему </span> <span>страшных </span> <span>болезнях </span> <span>, </span> <span>уносящих </span> <span>без </span> <span>малого </span> <span>1,5 </span> <span>млн </span> <span>жизней </span> <span>в </span> <span>России </span> <span>ежегодно </span></span></span><span>. </span><span>
#
#
#
#  </span><span>В </span><span>доковидные </span><span>годы </span><span>в </span><span>России </span><span>умирали </span><span>около </span><span>1 </span><span>800 </span><span>000 </span><span>человек </span><span>каждый </span><span>год </span><span>. </span><span>В </span><span>2020 </span><span>ковид </span><span>принес </span><span>дополнительных </span><span>160 </span><span>000 </span><span>смертей </span><span>, </span><span>если </span><span>верить </span><span>росстату </span><span>. </span><span key=80 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Примерно </span> <span>столько </span> <span>же </span> <span>людей </span> <span>умерли </span> <span>из </span> <span>- </span> <span>за </span> <span>методов </span> <span>борьбы </span> <span>с </span> <span>ковидом </span> <span>. </span></span></span><span>
#
#  </span><span key=82 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Я </span> <span>понимаю </span> <span>, </span> <span>что </span> <span>весь </span> <span>мир </span> <span>напуган </span> <span>страшным </span> <span>ковидом </span> <span>, </span> <span>от </span> <span>которого </span> <span>" </span> <span>люди </span> <span>падают </span> <span>замертво </span> <span>" </span> <span>, </span> <span>в </span> <span>" </span> <span>красной </span> <span>зоне </span> <span>" </span> <span>цепляются </span> <span>за </span> <span>жизнь </span> <span>и </span> <span>вообще </span> <span>всем </span> <span>ковид </span> <span>- </span> <span>диссидентам </span> <span>надо </span> <span>там </span> <span>побывать </span> <span>. </span> <span>К </span> <span>ежедневной </span> <span>статистике </span> <span>смертей </span> <span>во </span> <span>всем </span> <span>мире </span> <span>прибавляется </span> <span>по </span> <span>  </span> <span>несколько </span> <span>тысяч </span> <span>человек </span> <span>, </span> <span>умирающих </span> <span>от </span> <span>коронавируса </span></span></span><span>. </span><span>  </span><span>Это </span><span>не </span><span>мало </span><span>, </span><span>но </span><span>почему </span><span>- </span><span>то </span><span>подобной </span><span>паники </span><span>больше </span><span>не </span><span>вызывает </span><span>ни </span><span>одно </span><span>заболевание </span><span>и </span><span>ни </span><span>одна </span><span>другая </span><span>смерть </span><span>, </span><span>коих </span><span>гораздо </span><span>больше </span><span>
#
#  </span><span>Вернемся </span><span>в </span><span>грешную </span><span>Россию </span><span>, </span><span>ведь </span><span>в </span><span>этой </span><span>стране </span><span>я </span><span>живу </span><span>, </span><span>и </span><span>слежу </span><span>за </span><span>событиями </span><span>куда </span><span>более </span><span>внимательно </span><span>, </span><span>чем </span><span>за </span><span>всем </span><span>миром </span><span>. </span><span>
#
#  </span><span>Давайте </span><span>сравнивать </span><span>
#
#  </span><span>За </span><span>2020 </span><span>год </span><span>ковид </span><span>унес </span><span>примерно </span><span>70 </span><span>000 </span><span>жизней </span><span>( </span><span>по </span><span>данным </span><span>статистики </span><span>яндекса </span><span>) </span><span>и </span><span>около </span><span>160 </span><span>000 </span><span>жизней </span><span>по </span><span>данным </span><span>Росстат </span><span>( </span><span>такие </span><span>же </span><span>данные </span><span>озвучивают </span><span>и </span><span>другие </span><span>официальные </span><span>источники </span><span>) </span><span>. </span><span key=174 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>При </span> <span>этом </span> <span>молчит </span> <span>Росстат </span> <span>о </span> <span>более </span> <span>чем </span> <span>1 </span> <span>млн </span> <span>смертей </span> <span>от </span> <span>сердечно </span> <span>сосудистых </span> <span>заболеваний </span> <span>в </span> <span>2020 </span> <span>году </span> <span>и </span> <span>более </span> <span>чем </span> <span>300 </span> <span>000 </span> <span>случаев </span> <span>смертей </span> <span>от </span> <span>онкологии </span> <span>в </span> <span>России </span> <span>. </span> <span>То </span> <span>есть </span> <span>ССЗ </span> <span>и </span> <span>Рак </span> <span>становились </span> <span>причинами </span> <span>смертей </span> <span>в </span> <span>10 </span> <span>раз </span> <span>чаще </span> <span>чем </span> <span>ковид </span> <span>. </span></span></span><span>
#
#  </span><span key=176 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Для </span> <span>сравнения </span> <span>, </span> <span>смертность </span> <span>: </span> <span>
#
#  </span> <span>от </span> <span>ССЗ </span> <span>в </span> <span>2020 </span> <span>году </span> <span>умирал </span> <span>710 </span> <span>человек </span> <span>и </span> <span>100 </span> <span>000 </span> <span>россиян </span> <span>
#
#  </span> <sp
# 110
# <div style="padding: 16px;"><span key=0 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ЛЖЕ </span> <span>- </span> <span>ПАНДЕМИЯ </span> <span>КОРОНАВИРУСА </span> <span>- </span> <span>ВСЕМИРНАЯ </span> <span>АФЁРА </span></span></span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ВИДЕО </span><span>: </span><span>ВАКЦИННЫЙ </span><span>НАНО </span><span>- </span><span>БИОЧИП </span><span>ВСЕХ </span><span>СПАСЁТ </span><span>. </span><span>нано </span><span>- </span><span>биочип </span><span>под </span><span>видом </span><span>вакцины </span><span>. </span><span>интервью </span><span>билла </span><span>гейтса </span><span>от </span><span>4.11.2021 </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>27 </span><span>мая </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_437%2Fall </span><span>) </span><span>
#
#  </span><span>ВИДЕО </span><span>: </span><span>ВАКЦИННЫЙ </span><span>НАНО </span><span>- </span><span>БИОЧИП </span><span>ВСЕХ </span><span>СПАСЁТ </span><span>. </span><span key=47 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>нано </span> <span>- </span> <span>биочип </span> <span>под </span> <span>видом </span> <span>вакцины </span></span></span><span>. </span><span>интервью </span><span>билла </span><span>гейтса </span><span>от </span><span>4.11.2021 </span><span>. </span><span key=55 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>КОВИД </span> <span>- </span> <span>ФАШИСТ </span></span></span><span>БИЛЛ </span><span>ГЕЙТС </span><span>СКАЗАЛ </span><span>ПОЧТИ </span><span>СЛЕДУЮЩЕЕ </span><span>: </span><span key=62 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>БУРАТИНЫ </span> <span>ПЛАНЕТЫ </span> <span>ДУРАКОВ </span></span></span><span>! </span><span>НАНО </span><span>- </span><span>БИОЧИПЫ </span><span>, </span><span>КОТОРЫЕ </span><span>МЫ </span><span>ОБМАНОМ </span><span>ВСТАВЛЯЕМ </span><span>ВАМ </span><span>ПОД </span><span>ВИДОМ </span><span>ВАКЦИН </span><span>, </span><span>ЭТО </span><span>ОЧЕНЬ </span><span>КРУТО </span><span>И </span><span>ЗДОРОВО </span><span>! </span><span>ВИРУСЫ </span><span>БУДУТ </span><span>ОТСКАКИВАТЬ </span><span>ОТ </span><span>ВАКЦИННОГО </span><span>НАНО </span><span>- </span><span>БИОЧИПА </span><span>, </span><span>КАК </span><span>МЯЧИКИ </span><span>ОТ </span><span>СТЕНКИ </span><span>. </span><span>
#
#
#
#  </span><span>( </span><span>неизвестно </span><span>кто </span><span>это </span><span>- </span><span>оригинал </span><span>, </span><span>двойник </span><span>, </span><span>клон </span><span>, </span><span>цифрововой </span><span>аватар </span><span>от </span><span>ИИ </span><span>, </span><span>сделанный </span><span>с </span><span>помощью </span><span>технологии </span><span>видео </span><span>- </span><span>монтажа </span><span>и </span><span>обмана </span><span>Deep </span><span>Fake </span><span>или </span><span>старое </span><span>интервью </span><span>, </span><span>выданное </span><span>за </span><span>новое </span><span>) </span><span>. </span><span>
#
#  </span><span>так </span><span>как </span><span>мы </span><span>знаём </span><span>, </span><span>что </span><span>билл </span><span>гейтс </span><span>был </span><span>казнён </span><span>1.10.2021 </span><span>. </span><span>см. </span><span>ГУАНТАНАМО </span><span>. </span><span>ОГНЕННАЯ </span><span>ЗЕМЛЯ </span><span>. </span><span>хроника </span><span>спецопераций </span><span>, </span><span>арестов </span><span>и </span><span>трибуналов </span><span>над </span><span key=160 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ковид </span> <span>- </span> <span>фашистами </span> <span>. </span></span></span><span>
#
#  </span><span>СПРАВКА </span><span>: </span><span>- </span><span>поскольку </span><span>уже </span><span key=167 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>множество </span> <span>независимых </span> <span>учёных </span> <span>из </span> <span>разных </span> <span>стран </span> <span>провели </span> <span>научные </span> <span>исследования </span> <span>по </span> <span>ГМО </span> <span>- </span> <span>вакцинам </span></span></span><span>, </span><span>то </span><span>скрывать </span><span>и </span><span>дальше </span><span>уже </span><span>нет </span><span>смысла </span><span>. </span><span>мировое </span><span>правительство </span><span>через </span><span>билла </span><span>гейтса </span><span>подтвердило </span><span>, </span><span>что </span><span>их </span><span key=186 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ГМО </span> <span>- </span> <span>вакцины </span> <span>вовсе </span> <span>не </span> <span>вакцины </span> <span>, </span> <span>а </span> <span>чипы </span> <span>, </span> <span>или </span> <span>если </span> <span>точнее </span> <span>, </span> <span>то </span> <span>нано </span> <span>- </span> <span>биочипы </span> <span>. </span> <span>биочипы </span> <span>состоят </span> <span>из </span> <span>нано </span> <span>- </span> <span>частиц </span> <span>, </span> <span>например </span> <span>из </span> <span>оксида </span> <span>графена </span> <span>. </span> <span>оксид </span> <span>графена </span> <span>самовоспроизводится </span> <span>в </span> <span>нано </span> <span>- </span> <span>структуры </span> <span>, </span> <span>в </span> <span>нано </span> <span>- </span> <span>блоки </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span key=190 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>оксид </span> <span>графена </span> <span>создаёт </span> <span>надстройку </span> <span>в </span> <span>организме </span> <span>человека </span> <span>, </span> <span>сходную </span> <span>по </span> <span>аналогии </span> <span>с </span> <span>операционной </span> <span>системой </span> <span>майкрософт </span> <span>. </span> <span>оксид </span> <span>графена </span> <span>, </span> <span>попадая </span> <span>в </span> <span>организм </span> <span>человека </span> <span>, </span> <span>растёт </span> <span>питаясь </span> <span>за
# 111
# <div style="padding: 16px;"><span>Еще </span><span>новости </span><span>последнего </span><span>времени </span><span>- </span><span>ковид </span><span>- </span><span>паспорта </span><span>и </span><span>чипы </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Ключи </span><span>разумения </span><span>. </span><span>Апокалипсис </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YHWLxFuJH1EZy621 </span><span>( </span><span>14.04.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Уважаемый </span><span>читатель </span><span>, </span><span key=30 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>мы </span> <span>живем </span> <span>в </span> <span>такое </span> <span>время </span> <span>, </span> <span>когда </span> <span>новости </span> <span>, </span> <span>характеризующие </span> <span>наступление </span> <span>" </span> <span>последнего </span> <span>времени </span> <span>" </span> <span>- </span> <span>времени </span> <span>перед </span> <span>установлением </span> <span>власти </span> <span>антихриста </span> <span>и </span> <span>затем </span> <span>Вторым </span> <span>пришествием </span> <span>Христа </span> <span>, </span></span></span><span>выходят </span><span>чуть </span><span>ли </span><span>не </span><span>каждый </span><span>день </span><span>, </span><span>даже </span><span>несколько </span><span>раз </span><span>в </span><span>день </span><span>. </span><span>
#
#  </span><span>Приходится </span><span>очень </span><span>хорошо </span><span>отсеивать </span><span>информацию </span><span>, </span><span>потому </span><span>что </span><span key=53 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>много </span> <span>публикуется </span> <span>различных </span> <span>фейков </span></span></span><span>. </span><span>
#
#  </span><span>Мне </span><span>кажется </span><span>, </span><span key=59 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>что </span> <span>на </span> <span>это </span> <span>и </span> <span>расчет </span> <span>- </span> <span>публиковать </span> <span>огромную </span> <span>массу </span> <span>фейков </span> <span>и </span> <span>вместе </span> <span>с </span> <span>тем </span> <span>вполне </span> <span>реальные </span> <span>новости </span> <span>, </span> <span>чтобы </span> <span>снизить </span> <span>у </span> <span>людей </span> <span>уровень </span> <span>критической </span> <span>оценки </span> <span>событий </span></span></span><span>. </span><span>
#
#  </span><span>О </span><span>признаках </span><span>приближающей </span><span>власти </span><span>антихриста </span><span>я </span><span>писал </span><span>в </span><span>этой </span><span>статье </span><span>" </span><span>Признаки </span><span>приближающейся </span><span>власти </span><span>Антихриста </span><span>" </span><span>, </span><span>анализируя </span><span>некоторые </span><span>мировые </span><span>тренды </span><span>. </span><span>
#
#  </span><span>Буквально </span><span>на </span><span>днях </span><span>прочитал </span><span>сразу </span><span>несколько </span><span>новостей </span><span>, </span><span>некоторые </span><span>оказались </span><span>фейковыми </span><span>. </span><span>Например </span><span>, </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>вакцинах </span><span>будет </span><span>чип </span><span>от </span><span>Microsoft </span><span>оказалась </span><span>фейком </span><span>англоязычного </span><span>сатирического </span><span>  </span><span>сайта </span><span>. </span><span>
#
#  </span><span>Но </span><span>вот </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span key=125 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ученые </span> <span>Пентагона </span></span></span><span>разработали </span><span>микрочип </span><span>, </span><span>который </span><span>вводится </span><span>под </span><span>кожу </span><span>и </span><span>диагностирует </span><span>COVID-19 </span><span>, </span><span>и </span><span>этот </span><span>микрочип </span><span>реально </span><span>очень </span><span>маленький </span><span>- </span><span>вполне </span><span>реальна </span><span>. </span><span key=147 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Ее </span> <span>опубликовали </span> <span>такие </span> <span>известные </span> <span>издания </span> <span>как </span> <span>  </span> <span>the </span> <span>SUN </span> <span>, </span> <span>  </span> <span>NYPost </span> <span>, </span> <span>  </span> <span>Independent </span></span></span><span>  </span><span>и </span><span>другие </span><span>. </span><span>
#
#  </span><span key=153 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Будет </span> <span>ли </span> <span>этот </span> <span>чип </span> <span>начертанием </span> <span>? </span> <span>Нет </span> <span>. </span> <span>Но </span> <span>все </span> <span>это </span> <span>звенья </span> <span>в </span> <span>одной </span> <span>большой </span> <span>цепочке </span> <span>событий </span> <span>, </span> <span>как </span> <span>и </span> <span>другая </span> <span>новость </span> <span>их </span> <span>этого </span> <span>поста </span> <span>. </span></span></span><span>
#
#  </span><span>Одновременно </span><span>с </span><span>этим </span><span>в </span><span>европейской </span><span>  </span><span>прессе </span><span>  </span><span>появляется </span><span>высказывание </span><span>Тьерри </span><span key=166 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Бретона </span> <span>, </span> <span>европейского </span> <span>комиссара </span> <span>, </span> <span>возглавляющего </span> <span>целевую </span> <span>группу </span> <span>ЕС </span> <span>по </span> <span>вакцинам </span></span></span><span>, </span><span>который </span><span>говорит </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>начале </span><span>лета </span><span>, </span><span>с </span><span>15 </span><span>июня </span><span>, </span><span>будет </span><span>запущен </span><span>общеевропейский </span><span>паспорт </span><span>здоровья </span><span>, </span><span>паспорт </span><span>вакцинации </span><span>, </span><span>который </span><span>будет </span><span>содержать </span><span>
# 115
# <div style="padding: 16px;"><span>Ковид </span><span>стоит </span><span>триллиарды </span><span>долларов </span><span>. </span><span>Правда </span><span>, </span><span>от </span><span>которой </span><span>не </span><span>убежать </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Родина </span><span>Слонов </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YP5vrjuTmlH6WvYm </span><span>( </span><span>27.07.2021 </span><span>) </span><span>
#
#
#
#  </span><span key=26 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Дочитайте </span> <span>эту </span> <span>статью </span> <span>до </span> <span>конца </span> <span>- </span> <span>и </span> <span>вы </span> <span>согласитесь </span> <span>, </span> <span>что </span> <span>коронавирус </span> <span>стал </span> <span>очень </span> <span>своевременным </span> <span>и </span> <span>очень </span> <span>выгодным </span> <span>решением </span></span></span><span>. </span><span>И </span><span>знаете </span><span>, </span><span>для </span><span>кого </span><span>конкретно </span><span>? </span><span>
#
#  </span><span>Чтобы </span><span>объяснить </span><span>, </span><span>откуда </span><span>автору </span><span>пришло </span><span>озарение </span><span>на </span><span>эту </span><span>тему </span><span>, </span><span>нужно </span><span>сообщить </span><span>, </span><span>что </span><span>идёт </span><span>пятый </span><span>день </span><span>моих </span><span>мучений </span><span>с </span><span>этим </span><span>заболеванием </span><span>. </span><span>На </span><span>третий </span><span>день </span><span>сделал </span><span>ПЦР </span><span>- </span><span>тест </span><span>, </span><span>на </span><span>четвертый </span><span>- </span><span>тест </span><span>вышел </span><span>положительным </span><span>. </span><span key=75 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>А </span> <span>ведь </span> <span>я </span> <span>так </span> <span>хорошо </span> <span>и </span> <span>удачно </span> <span>проскочил </span> <span>через </span> <span>первые </span> <span>две </span> <span>волны </span> <span>, </span> <span>что </span> <span>уже </span> <span>считал </span> <span>себя </span> <span>бессмертным </span> <span>и </span> <span>неуязвимым </span> <span>, </span> <span>как </span> <span>горец </span> <span>... </span> <span>Теперь </span> <span>— </span> <span>мучение </span> <span>- </span> <span>лечение </span></span></span><span>, </span><span>да </span><span>ещё </span><span>пришлось </span><span>отказаться </span><span>от </span><span>экспедиции </span><span>на </span><span>Перевал </span><span>Дятлова </span><span>( </span><span>а </span><span>готовилась </span><span>она </span><span>полгода </span><span>) </span><span>, </span><span>ну </span><span>в </span><span>- </span><span>общем </span><span>, </span><span>расклад </span><span>для </span><span>старта </span><span>мыслей </span><span>был </span><span>позитивный </span><span>... </span><span>
#
#  </span><span key=106 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Откуда </span> <span>и </span> <span>для </span> <span>чего </span> <span>могла </span> <span>взяться </span> <span>проклятая </span> <span>ковидла </span> <span>— </span> <span>и </span> <span>, </span> <span>главное </span> <span>, </span> <span>когда </span> <span>это </span> <span>всё </span> <span>нас </span> <span>окончательно </span> <span>минует </span> <span>? </span></span></span><span>
#
#  </span><span>Помните </span><span>старый </span><span>анекдот </span><span>, </span><span>как </span><span>заработать </span><span>трём </span><span>программистам </span><span>? </span><span>Один </span><span>пишет </span><span>вирусы </span><span>, </span><span>второй </span><span>антивирусы </span><span>, </span><span>а </span><span>третий </span><span>- </span><span>программное </span><span>обеспечение </span><span>, </span><span>в </span><span>котором </span><span>всё </span><span>это </span><span>работает </span><span>. </span><span>
#
#  </span><span>Для </span><span>тех </span><span>, </span><span>кто </span><span>с </span><span>ходу </span><span>уже </span><span>думает </span><span>, </span><span>что </span><span>просёк </span><span>нить </span><span>разговора </span><span>, </span><span>можете </span><span>сразу </span><span>листнуть </span><span>вниз </span><span>, </span><span>до </span><span>комментариев </span><span>, </span><span>и </span><span>там </span><span>оставить </span><span>отметку </span><span>наподобие </span><span>" </span><span>Автор </span><span>, </span><span>браво </span><span>, </span><span>всё </span><span>верняк </span><span>, </span><span>пиши </span><span>исчо </span><span>" </span><span>или </span><span>просто </span><span>" </span><span>Здесь </span><span>был </span><span>Вася </span><span>" </span><span>или </span><span>даже </span><span>" </span><span>Как </span><span>обычно </span><span>, </span><span>полная </span><span>чушь </span><span>" </span><span>( </span><span>последнее </span><span>, </span><span>правда </span><span>, </span><span>не </span><span>столь </span><span>эпично </span><span>) </span><span>. </span><span>
#
#  </span><span>А </span><span>тем </span><span>, </span><span>кто </span><span>решит </span><span>прочитать </span><span>полностью </span><span>- </span><span>вы </span><span>молодцы </span><span>, </span><span>я </span><span>заранее </span><span>вами </span><span>горжусь </span><span>, </span><span>пытливые </span><span>умы </span><span>. </span><span>
#
#
#
#  </span><span>Это </span><span>была </span><span>, </span><span>конечно </span><span>, </span><span>шутка </span><span>, </span><span>от </span><span>моего </span><span>любимого </span><span>юмористического </span><span>журнала </span><span>" </span><span>Красная </span><span>Бурда </span><span>" </span><span>. </span><span>А </span><span>вот </span><span key=241 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>что </span> <span>не </span> <span>является </span> <span>шуткой </span> <span>, </span> <span>так </span> <span>это </span> <span>факт </span> <span>, </span> <span>что </span> <span>  </span> <span>вирус </span> <span>- </span> <span>то </span> <span>напоминает </span> <span>боевой </span> <span>. </span></span></span><span>Это </span><span>было </span><span>понятно </span><span>, </span><span>когда </span><span>выяснилась </span><span>его </span><span>особенность </span><span>в </span><span>виде </span><span>отключения </span><span>обоняния </span><span>( </span><span>или </span><span>" </span><span>нюха </span><span>" </span><span>, </span><span>как </span><span>любят </span><span>говорить </span><span>в </span><span>России </span><span>) </span><span>- </span><span>интересненький </span><span>эксперимент </span><span>по </span><span>лишению </span><span>человека </span><span>конкретной </span><span>функции </span><span>( </span><span>сегодня </span><span>- </span><span>нос </span><span>, </span><span>завтра </span><span>- </span><span>руку </span
# 12
# <div style="padding: 16px;"><span>Кинология </span><span>для </span><span>каждого </span><span>. </span><span>Все </span><span>о </span><span>собаках </span><span>и </span><span>не </span><span>только </span><span>. </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>4 </span><span>января </span><span>( </span><span>) </span><span>
#
#
#
#  </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>. </span><span>Автор </span><span>Ирина </span><span>Видус </span><span>
#
#  </span><span>- </span><span>У </span><span>собачников </span><span>очень </span><span>сильный </span><span>иммунитет </span><span>, </span><span>ведь </span><span>они </span><span>рано </span><span>встают </span><span>и </span><span>ежедневно </span><span>гуляют </span><span>по </span><span>2 </span><span>- </span><span>3 </span><span>часа </span><span>в </span><span>любую </span><span>погоду </span><span>
#  </span><span>- </span><span key=60 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>А </span> <span>ещё </span> <span>их </span> <span>иммунитет </span> <span>натренирован </span> <span>, </span> <span>ведь </span> <span>он </span> <span>каждый </span> <span>день </span> <span>сталкивается </span> <span>с </span> <span>кучей </span> <span>бактерий </span> <span>/ </span> <span>вирусов </span> <span>и </span> <span>успешно </span> <span>их </span> <span>побеждает </span> <span>. </span></span></span><span>
#  </span><span>- </span><span>У </span><span>собачника </span><span>крепкая </span><span>нервная </span><span>система </span><span>, </span><span>а </span><span>это </span><span>неплохой </span><span>щит </span><span>для </span><span>любой </span><span>инфекции </span><span>. </span><span>Собачник </span><span>каждый </span><span>день </span><span>противостоит </span><span>догхантерам </span><span>, </span><span>
#  </span><span>яжематерям </span><span>, </span><span>собаконенавистникам </span><span>и </span><span>не </span><span>теряет </span><span>бодрость </span><span>духа </span><span>и </span><span>оптимизм </span><span>. </span><span>Собачники </span><span>умеют </span><span>радоваться </span><span>каждому </span><span>пустяку </span><span>, </span><span>любить </span><span>природу </span><span>, </span><span>братьев </span><span>наших </span><span>меньших </span><span>. </span><span>Они </span><span>не </span><span>пойдут </span><span>скупать </span><span>гречку </span><span>и </span><span>туалетную </span><span>бумагу </span><span>. </span><span>Пожалуй </span><span>, </span><span>собачник </span><span>купит </span><span>новый </span><span>мячик </span><span>щенку </span><span>и </span><span>капли </span><span>с </span><span>ошейником </span><span>от </span><span>блох </span><span>и </span><span>клещей </span><span>для </span><span>взрослой </span><span>собаки </span><span>. </span><span>
#  </span><span>- </span><span key=138 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Собачники </span> <span>живут </span> <span>по </span> <span>четкому </span> <span>режиму </span> <span>, </span> <span>они </span> <span>очень </span> <span>рано </span> <span>встают </span> <span>, </span> <span>выходят </span> <span>гулять </span> <span>с </span> <span>собакой </span> <span>в </span> <span>одно </span> <span>и </span> <span>то </span> <span>же </span> <span>время </span> <span>, </span> <span>кормят </span> <span>щенков </span> <span>по </span> <span>часам </span> <span>. </span> <span>Собачники </span> <span>не </span> <span>тусят </span> <span>в </span> <span>клубах </span> <span>, </span> <span>редко </span> <span>проводят </span> <span>время </span> <span>в </span> <span>ТЦ </span> <span>, </span> <span>не </span> <span>жалуют </span> <span>алкоголь </span> <span>и </span> <span>сигареты </span> <span>, </span> <span>потому </span> <span>что </span> <span>этот </span> <span>запах </span> <span>не </span> <span>любят </span> <span>их </span> <span>хвостики </span> <span>. </span> <span>Обожают </span> <span>поля </span> <span>, </span> <span>леса </span> <span>, </span> <span>походы </span> <span>, </span> <span>поездки </span> <span>за </span> <span>город </span> <span>и </span> <span>дачу </span> <span>. </span> <span>Могут </span> <span>прилечь </span> <span>днем </span> <span>спать </span> <span>вместе </span> <span>с </span> <span>любимыми </span> <span>хвостиками </span> <span>, </span> <span>нагулявшись </span> <span>в </span> <span>лесу </span> <span>. </span> <span>Подобный </span> <span>иммунный </span> <span>щит </span> <span>и </span> <span>здоровый </span> <span>образ </span> <span>жизни </span> <span>неплохо </span> <span>противостоит </span> <span>вирусам </span></span></span><span>. </span><span>
#  </span><span>- </span><span>Собачники </span><span>и </span><span>без </span><span>того </span><span>сидят </span><span>на </span><span>карантине </span><span>. </span><span>Сперва </span><span>исчезают </span><span>родственники </span><span>, </span><span>потом </span><span>" </span><span>друзья </span><span>" </span><span>, </span><span>затем </span><span>и </span><span>соседи </span><span>перестают </span><span>захаживать </span><span>. </span><span>Любимая </span><span>фраза </span><span>собачника:"чем </span><span>меньше </span><span>вокруг </span><span>народа </span><span>, </span><span>тем </span><span>лучше </span><span>для </span><span>моей </span><span>собаки </span><span>" </span><span>. </span><span>
#  </span><span>- </span><span key=181 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Собачник </span> <span>смело </span> <span>может </span> <span>тереть </span> <span>нос </span> <span>и </span> <span>глаза </span> <span>рукой </span> <span>. </span> <span>Кожный </span> <span>и </span> <span>общий </span> <span>иммунитет </span> <span>собаковода </span> <span>всегда </span> <span>на </span> <span>высоте </span> <span>, </span> <span>после </span> <span>того </span> <span>как </span> <span>лицо </span> <span>каждый </span> <span>день </span> <span>облизывает </span> <span>любимая </span> <span>собака </span> <span>. </span> <span>Тем </span> <span>более </span> <span>слюна </span> <span>содержит </span> <span>не </span> <span>только </span> <span>бактерии </span> <span>, </span> <span>но </span> <span>и </span> <span>лизоцим </span> <span>, </span> <span>повышающий </span> <span>иммунитет </span> <span>и </span> <span>оказывающий </span> <span>
#  </span> <span>бактерицидное </span> <span>действие </span> <span>. </span> <span>А </span> <span>от </span> <span>" </span> <span>носоцелования </span> <span>" </span> <span>не </span> <span>откажется </span> <span>в </span> <span>здравом </span> <span>смысле </span> <span>ни </span> <span>один </span> <span>владелец </span> <span>пса </span> <span>. </span> <span>Так </span> <span>же </span> <span>многие </span> <span>собачники </span> <span>пускают </span> <span>собак </span> <span>в </span> <span>постель </span> <span>, </span> <span>что </span> <span>плавно </span> <span>, </span> <span>изо </span> <span>дня </span> <span>в </span> <span>день </span> <span>, </span> <span>закаливает </sp
# 122
# <div style="padding: 16px;"><span>Сергей </span><span>Кургинян </span><span>выступил </span><span>против </span><span>пропаганды </span><span>развёрнутой </span><span>вокруг </span><span>защитной </span><span>процедуры </span><span>от </span><span>вируса </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Отражение </span><span>Реальности </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YX76gx7rIk3hmxmu </span><span>( </span><span>02.11.2021 </span><span>) </span><span>
#
#
#
#  </span><span key=26 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Лично </span> <span>я </span> <span>про </span> <span>Сергея </span> <span>Кургиняна </span> <span>узнал </span> <span>лишь </span> <span>вчера </span> <span>. </span></span></span><span>И </span><span>он </span><span>, </span><span>таки </span><span>, </span><span>смог </span><span>меня </span><span>удивить </span><span>! </span><span>
#
#
#
#  </span><span>Но </span><span>удивил </span><span>он </span><span>меня </span><span>не </span><span>этим </span><span>. </span><span>Сейчас </span><span>много </span><span>кто </span><span>и </span><span>много </span><span>чего </span><span>объясняет </span><span>по </span><span>этому </span><span>поводу </span><span>. </span><span>Удивил </span><span key=56 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>меня </span> <span>Кургинян </span> <span>своей </span> <span>неистовостью </span> <span>! </span> <span>Ему </span> <span>больше </span> <span>70 </span> <span>лет </span> <span>, </span> <span>уже </span> <span>, </span> <span>а </span> <span>он </span> <span>полон </span> <span>боевого </span> <span>задора </span> <span>и </span> <span>не </span> <span>трусит </span> <span>! </span></span></span><span>
#
#  </span><span>Я </span><span>размещу </span><span>в </span><span>этой </span><span>статье </span><span>видео </span><span>с </span><span>его </span><span>выступлением </span><span>на </span><span>злободневную </span><span>тему </span><span>. </span><span key=71 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Если </span> <span>вы </span> <span>, </span> <span>как </span> <span>и </span> <span>я </span> <span>, </span> <span>впервые </span> <span>смотрите </span> <span>на </span> <span>интервью </span> <span>с </span> <span>этим </span> <span>человеком </span> <span>, </span> <span>то </span> <span>вы </span> <span>, </span> <span>полагаю </span> <span>, </span> <span>удивитесь </span> <span>не </span> <span>меньше </span> <span>чем </span> <span>я </span> <span>! </span></span></span><span>
#
#  </span><span>Кургинян </span><span>объяснил </span><span>, </span><span>в </span><span>чем </span><span>заключается </span><span>главная </span><span>опасность </span><span>сегодняшней </span><span>ситуации </span><span>с </span><span>вaкциинaциeй </span><span>: </span><span>
#
#  </span><span>Я </span><span>размещаю </span><span>здесь </span><span>описание </span><span>, </span><span>в </span><span>виде </span><span>скриншотов </span><span>с </span><span>канала </span><span>на </span><span>Ютубе </span><span>, </span><span>нижеприведённого </span><span>ролика </span><span>, </span><span>чтобы </span><span>вам </span><span>было </span><span>легче </span><span>ориентироваться </span><span>. </span><span>
#
#  </span></div>
# 123
# <div style="padding: 16px;"><span key=0 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ЛЖЕ </span> <span>- </span> <span>ПАНДЕМИЯ </span> <span>КОРОНАВИРУСА </span> <span>- </span> <span>ВСЕМИРНАЯ </span> <span>АФЁРА </span></span></span><span>( </span><span>2022 </span><span>) </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span key=15 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Рикардо </span> <span>Дельгадо </span> <span>об </span> <span>окончательном </span> <span>заключении </span> <span>экспертов </span> <span>: </span> <span>ВСЕ </span> <span>СОВРЕМЕННЫЕ </span> <span>" </span> <span>ВАКЦИНЫ </span> <span>" </span> <span>СОДЕРЖАТ </span> <span>ИСКЛЮЧИТЕЛЬНО </span> <span>НАНО </span> <span>- </span> <span>ТЕХНОЛОГИИ </span> <span>: </span> <span>НАНО </span> <span>- </span> <span>РОУТЕРЫ </span> <span>, </span> <span>НАНО </span> <span>- </span> <span>РЕТЕННЫ </span> <span>, </span> <span>КОДЕКИ </span> <span>, </span> <span>НАНО </span> <span>- </span> <span>АНТЕННЫ </span> <span>, </span> <span>КОТОРЫЕ </span> <span>ПЕРЕДАЮТ </span> <span>МАК </span> <span>- </span> <span>АДРЕСА </span> <span>НА </span> <span>СЕРВЕР </span> <span>ИИ </span> <span>. </span></span></span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>14 </span><span>апреля </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_415%2Fall </span><span>) </span><span>
#
#
#
#  </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span>Рикардо </span><span>Дельгадо </span><span>об </span><span>окончательном </span><span>заключении </span><span>экспертов </span><span>: </span><span>ВСЕ </span><span>СОВРЕМЕННЫЕ </span><span>" </span><span>ВАКЦИНЫ </span><span>" </span><span>СОДЕРЖАТ </span><span>ИСКЛЮЧИТЕЛЬНО </span><span>НАНО </span><span>- </span><span>ТЕХНОЛОГИИ </span><span>: </span><span>НАНО </span><span>- </span><span>РОУТЕРЫ </span><span>, </span><span>НАНО </span><span>- </span><span>РЕТЕННЫ </span><span>, </span><span>КОДЕКИ </span><span>, </span><span>НАНО </span><span>- </span><span>АНТЕННЫ </span><span>, </span><span>КОТОРЫЕ </span><span>ПЕРЕДАЮТ </span><span>МАК </span><span>- </span><span>АДРЕСА </span><span>НА </span><span>СЕРВЕР </span><span>ИИ </span><span>. </span><span>Что </span><span>содержат </span><span>" </span><span>вакцины </span><span>" </span><span>и </span><span>как </span><span>это </span><span>влияет </span><span>на </span><span>человека </span><span>. </span><span>доктор </span><span>рикардо </span><span>дельгадо </span><span>. </span><span>
#
#  </span><span>СОДЕРЖАНИЕ </span><span>ВИДЕО </span><span>: </span><span>
#
# ...
#
#  </span><span>Первого </span><span>декабря </span><span>2019 </span><span>года </span><span>в </span><span>Ухане </span><span>был </span><span>зарегистрирован </span><span>первый </span><span>случай </span><span>пневмонии </span><span>неизвестной </span><span>этиологии </span><span>. </span><span>Это </span><span>произошло </span><span>три </span><span>года </span><span>назад </span><span>. </span><span key=47 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>В </span> <span>опубликованном </span> <span>докладе </span> <span>международного </span> <span>союза </span> <span>учёных </span> <span>в </span> <span>журнале </span> <span>« </span> <span>The </span> <span>Lancet </span> <span>» </span></span></span><span>говорится </span><span>, </span><span>что </span><span>одой </span><span>из </span><span>главнейших </span><span>версий </span><span>происхождения </span><span>COVID-19 </span><span>является </span><span>лабораторное </span><span>происхождение </span><span>. </span><span>
#
#  </span><span>По </span><span>поводу </span><span>журнала </span><span>« </span><span>The </span><span>Lancet </span><span>» </span><span>. </span><span>Я </span><span>ещё </span><span>тогда </span><span>говорил </span><span>о </span><span>том </span><span>, </span><span>что </span><span>происхождение </span><span>этого </span><span>вируса </span><span>крайне </span><span>подозрительное </span><span>. </span><span>Исключать </span><span>его </span><span>искусственное </span><span>происхождение </span><span>нельзя </span><span>. </span><span key=90 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Хотя </span> <span>у </span> <span>нас </span> <span>многие </span> <span>, </span> <span>включая </span> <span>и </span> <span>наших </span> <span>руководителей </span> <span>, </span> <span>говорили </span> <span>, </span> <span>что </span> <span>это </span> <span>маловероятно </span> <span>. </span></span></span><span>И </span><span>вся </span><span>эта </span><span>шумиха </span><span>, </span><span>связанная </span><span>с </span><span>ним </span><span>, </span><span>явно </span><span>была </span><span>искусственно </span><span>подогреваема </span><span>. </span><span>Зачем </span><span>мы </span><span>к </span><span>ней </span><span>подключились </span><span>, </span><span>особенно </span><span>на </span><span>первом </span><span>этапе </span><span>, </span><span>для </span><span>меня </span><span>до </span><span>сих </span><span>пор </span><span>является </span><span>загадкой </span><span>. </span><span>
#
#  </span><span>Но </span><span>главное </span><span>сейчас </span><span>заключается </span><span>в </span><span>том </span><span>, </span><span>что </span><span>в </span><span>следующий </span><span>раз </span><span>надо </span><span>быть </span><span>умнее </span><span>. </span><span key=140 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Это </span> <span>к </span> <span>вопросу </span> <span>о </span> <span>том </span> <span>: </span> <span>« </span> <span>Смотрите </span> <span>, </span> <span>все </span> <span>побежали </span> <span>, </span> <span>и </span> <span>мы </span> <span>побежали </span> <span>. </span> <span>Европа </span> <span>, </span> <span>Америка </span> <span>, </span> <span>Китай </span> <span>, </span> <span>карантин </span> <span>, </span> <span>давай </span> <span>всех </span> <span>колоть </span> <span>! </span> <span>Давайте </span> <span>и </span> <span>мы </span> <span>тоже </span> <span>будем </span> <span>всё </span> <span>это </span> <span>делать </span> <span>! </span> <span>» </span> <span>. </span> <span>А </span> <span>в </span> <span>итоге </span> <span>, </span> <span>началась </span> <span>СВО </span> <span>, </span> <span>и </span> <span>вирус </span> <span>закончился </span> <span>сам </span> <span>собой </span> <span>. </span></span></span><span>
#
#  </span><span>Это </span><span>как </span><span>шутили </span><span>, </span><span>что </span><span>Владимир </span><span>Путин </span><span>одним </span><span>росчерком </span><span>пера </span><span>завершил </span><span>пандемию </span><span>коронавируса </span><span>. </span><span key=156 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Это </span> <span>говорит </span> <span>о </span> <span>простой </span> <span>вещи </span> <span>: </span> <span>может </span> <span>быть </span> <span>, </span> <span>и </span> <span>не </span> <span>надо </span> <span>было </span> <span>такой </span> <span>бешеной </span> <span>паники </span> <span>развивать </span> <span>, </span> <span>людей </span> <span>так </span> <span>напрягать </span> <span>, </span> <span>нервировать </span> <span>? </span></span></span><span>И </span><span>не </span><span>надо </span><span>было </span><span>повторять </span><span>всё </span><span>то </span><span>, </span><span>что </span><span>было </span><span>навязано </span><span key=168 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Всемирной </span> <span>организацией </span> <span>здравоохранения </span> <span>и </span> <span>поддержано </span> <span>всеми </span> <span>этими </span> <span>глобалистскими </span> <span>элитами </span></span></span><span>. </span><span key=170 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>На </span> <span>самом </span> <span>деле </span> <span>, </span> <span>всё </span> <span>то </span> <span>, </span> <span>что </span> <span>здесь </span> <span>происходило </span> <span>по </span> <span>ковиду </span> <span>, </span> <span>это </span> <span>была </span> <span>калька </span> <span>с </span> <span>западных </span> <span>практик </span> <span>, </span> <span>а </span> <span>так </span> <span>же </span> <span>прямое </span> <span>выполнение </span> <span>указаний </span> <span>глобалистских </span> <span>организаций </span> <span>здравоохранения </span> <span>. </span></span></span><span>Это </span><span>первое </span><span>. </span><span>
#
#  </span><span>Второе </span><span>даже </span><span>интереснее </span><span>. </span><span>Вот </span><span>это </span><span>мнение </span><span>учёных </span><span>, </spa
# 99
# <div style="padding: 16px;"><span>Преступления </span><span>ковид </span><span>- </span><span>фашистов </span><span>мирового </span><span>правит </span><span>- </span><span>ства </span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span key=15 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>КОВИД </span> <span>- </span> <span>ФАШИСТА </span></span></span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span key=21 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>НЕОФАШИСТОВ </span></span></span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span key=25 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>НОВЫХ </span> <span>ГИТЛЕРОВ </span></span></span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>29 </span><span>ноября </span><span>( </span><span>https://vk.com/public201975126?w=wall-201975126_973 </span><span>) </span><span>
#
#
#
#  </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span key=46 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>КОВИД </span> <span>- </span> <span>ФАШИСТА </span></span></span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span key=52 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>НЕОФАШИСТОВ </span></span></span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span key=56 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>НОВЫХ </span> <span>ГИТЛЕРОВ </span></span></span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>ВИДЕО </span><span>. </span><span>
#
#  </span><span>- </span><span>Школа </span><span>диктаторов </span><span key=69 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>ковид </span> <span>- </span> <span>фашиста </span> <span>Клауса </span> <span>Шваба </span> <span>( </span> <span>ротшильда </span> <span>) </span></span></span><span>, </span><span>или </span><span>план </span><span>великой </span><span>перезагрузки </span><span>. </span><span>9 </span><span>дек. </span><span>2021 </span><span>г. </span><span>
#
#  </span><span>- </span><span key=82 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>новые </span> <span>гитлеры </span></span></span><span>готовятся </span><span>в </span><span>ВЭФ </span><span>для </span><span>проведения </span><span key=88 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>всемирных </span> <span>спецопераций </span></span></span><span>: </span><span>
#
#  </span><span key=91 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>лже-"вакцинация </span> <span>" </span> <span>, </span> <span>лже </span> <span>- </span> <span>ПЦР </span> <span>- </span> <span>тестизация </span></span></span><span>, </span><span>QR </span><span>- </span><span>кодизация </span><span>, </span><span>цифровизация </span><span>, </span><span key=99 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>зомби- </span> <span>и </span> <span>НЛП </span> <span>- </span> <span>пропаганда </span> <span>существования </span> <span>пандемий </span> <span>, </span> <span>штаммов </span> <span>, </span> <span>вирусов </span> <span>, </span> <span>которые </span> <span>на </span> <span>самом </span> <span>деле </span> <span>не </span> <span>существуют </span> <span>, </span> <span>спонсирование </span> <span>на </span> <span>частном </span> <span>и </span> <span>государственном </span> <span>уровне </span> <span>лже </span> <span>- </span> <span>учёных </span></span></span><span>, </span><span>которые </span><span>скрывают </span><span>, </span><span>что </span><span>нано </span><span>- </span><span>частицы </span><span>, </span><span>нано </span><span>- </span><span>технологии </span><span>и </span><span>5 </span><span>джи </span><span>- </span><span>смертоносны </span><span>и </span><span>вредны </span><span>для </span><span>здоровья </span><span>и </span><span>иммунной </span><span>системы </span><span key=124 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>человека </span></span></span><span>. </span><span>
#
#
#
#  </span><span>- </span><span key=128 class="highlight blue" depth=0 id=PROP onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>PROP</strong></span>                <span class="highlight__content"><span>Одна </span> <span>из </span> <span>целей </span> <span>нынешней </span> <span>политики </span> <span>мирового </span> <span>правительства </span> <span>, </span> <span>проводимой </span> <span>правительствами </span> <span>многих </span> <span>стран </span> <span>, </span> <span>состоит </span> <span>в </span> <span>том </span> <span>, </span> <span>чтобы </span> <span>разрушить </span> <span>бизнес </span> <span>малых </span> <span>и </span> <span>средних </spa

# %% [markdown]
# ## Technique classification

# %%
def load_result(file):
    result = defaultdict(dict)
    with open(file, "r") as f:
        for line in f:
            article_id, prediction, spl, spr = line.split('\t')
            result[article_id].setdefault(prediction, [])
            result[article_id][prediction].append([int(spl), int(spr)])
    return result


def show_result(result, articles_id, articles_content, top=None):
    showed = 0
    articles = dict(zip(articles_id, articles_content))
    for article_id in sorted(result):
        text = articles[article_id]
        nlp_text = nlp(text)
        tokens_idx = np.array([token.idx for token in nlp_text])
        tokens = [token.text for token in nlp_text]
        
        spans = [[] for _ in range(len(mapping))]
        for cluster in result[article_id]:
            for sp in result[article_id][cluster]:
                sp[0] = np.where(tokens_idx >= sp[0])[0][0]
                sp[1] = np.where(tokens_idx < sp[1])[0][-1]
                spans[inverse_mapping[cluster]].append([sp[0], sp[1]])
        
        if len(spans) != 0:
            print(colored(article_id, 'red'))
            #show_box_markup(text, spans, palette=palette(PROP=BLUE))
            visualization.render(tokens, spans, task='TC')
            showed += 1
            if top is not None and showed > top:
                break
                
                
mapping = {i: el for i, el in enumerate(['Negative/Positive_concepts',
 '(PT)_Call',
 'Slogan',
 'Obfuscation,vagueness,obscurantism',
 'Consequential_Simplification',
 'Greenwashing',
 'Causal_Simplification',
 'Appeal_to_Hypocrisy',
 'Appeal_to_values',
 'Rumours',
 'Strawman',
 'Whataboutism',
 'Hate_speech,slang,name_calling',
 'Casting_Doubt',
 'Labelling',
 'Substitution_of_an_idea',
 'Statistical_deception',
 'Bluewashing',
 'Appeal_to_authority',
 'Guilt_by_Association',
 'Appeal_to_Time',
 'Flag_waving',
 '“you_should”',
 'Simplified_Interpretation',
 'Appeal_to_fear/prejudice',
 'Loaded_language',
 'Sensational_and/or_provocative_headings',
 '“I_am_like_you”',
 'Exaggeration/Minimization',
 'Red_Herring',
 'Appeal_to_popularity',
 'Repetition',
 'False_Dilemma',
 'Distraction_by_scapegoat',
 'Conversation_Killer',
 'Stereotypes'])}

inverse_mapping = {b:a for (a, b) in mapping.items()}

# %%
articles_content, articles_id, _ = load_data('../datasets/dev-articles', 
                                             '../tools/data/russian_corpus_techniques.txt')
result = load_result('../results/TC_output_dev_sc.txt')
show_result(result, articles_id, articles_content)
# Out:
# 103
# <div style="padding: 16px;"><span>Почему </span><span>нет </span><span>паники </span><span>по </span><span>действительно </span><span>опасным </span><span>заболеваниям </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>ПМЗ </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YExyWq9Bo2ZBiLA7 </span><span>( </span><span>30.03.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Если </span><span>вы </span><span>это </span><span key=24 class="highlight pink" depth=0 id=Statistical_deception onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Statistical_deception</strong></span>                <span class="highlight__content"><span>читаете </span> <span>, </span> <span>значит </span> <span>вам </span> <span>повезло </span> <span>не </span> <span>попасть </span> <span>почти </span> <span>в </span> <span>1,5 </span> <span>% </span> <span>россиян </span> <span>умерших </span> <span>в </span> <span>2020 </span> <span>году </span> <span>. </span> <span>Вы </span> <span>оказались </span> <span>счастливее </span> <span>2,1 </span> <span>млн </span> <span>человек </span> <span>. </span> <span>На </span> <span>этом </span> <span>хорошие </span> <span>новости </span> <span>заканчиваются </span> <span>. </span> <span>А </span> <span>теперь </span> <span>поговорим </span> <span>о </span> <span>по </span> <span>настоящему </span> <span>страшных </span> <span>болезнях </span> <span>, </span> <span>уносящих </span> <span>без </span> <span>малого </span> <span>1,5 </span> <span>млн </span> <span>жизней </span> <span>в </span> <span>России </span> <span>ежегодно </span></span></span><span>. </span><span>
#
#
#
#  </span><span>В </span><span>доковидные </span><span>годы </span><span>в </span><span>России </span><span>умирали </span><span>около </span><span>1 </span><span>800 </span><span>000 </span><span>человек </span><span>каждый </span><span>год </span><span>. </span><span>В </span><span>2020 </span><span>ковид </span><span>принес </span><span>дополнительных </span><span>160 </span><span>000 </span><span>смертей </span><span>, </span><span>если </span><span>верить </span><span>росстату </span><span>. </span><span>Примерно </span><span>столько </span><span>же </span><span>людей </span><span>умерли </span><span>из </span><span>- </span><span>за </span><span>методов </span><span>борьбы </span><span>с </span><span>ковидом </span><span>. </span><span>
#
#  </span><span>Я </span><span key=69 class="highlight fuchsia" depth=0 id=Loaded_language onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Loaded_language</strong></span>                <span class="highlight__content"><span>понимаю </span> <span>, </span> <span>что </span> <span>весь </span> <span>мир </span> <span>напуган </span> <span>страшным </span> <span>ковидом </span> <span>, </span> <span>от </span> <span>которого </span> <span>" </span> <span>люди </span> <span>падают </span> <span>замертво </span> <span>" </span> <span>, </span> <span>в </span> <span>" </span> <span>красной </span> <span>зоне </span> <span>" </span> <span>цепляются </span> <span>за </span> <span>жизнь </span> <span>и </span> <span>вообще </span> <span>всем </span> <span>ковид </span> <span>- </span> <span>диссидентам </span> <span>надо </span> <span>там </span> <span>побывать </span> <span>. </span> <span>К </span> <span>ежедневной </span> <span>статистике </span> <span>смертей </span> <span>во </span> <span>всем </span> <span>мире </span> <span>прибавляется </span> <span>по </span> <span>  </span> <span>несколько </span> <span>тысяч </span> <span>человек </span> <span>, </span> <span>умирающих </span> <span>от </span> <span>коронавируса </span></span></span><span>. </span><span>  </span><span>Это </span><span>не </span><span>мало </span><span>, </span><span>но </span><span>почему </span><span>- </span><span>то </span><span>подобной </span><span>паники </span><span>больше </span><span>не </span><span>вызывает </span><span>ни </span><span>одно </span><span>заболевание </span><span>и </span><span>ни </span><span>одна </span><span>другая </span><span>смерть </span><span>, </span><span>коих </span><span>гораздо </span><span>больше </span><span>
#
#  </span><span>Вернемся </span><span>в </span><span>грешную </span><span>Россию </span><span>, </span><span>ведь </span><span>в </span><span>этой </span><span>стране </span><span>я </span><span>живу </span><span>, </span><span>и </span><span>слежу </span><span>за </span><span>событиями </span><span>куда </span><span>более </span><span>внимательно </span><span>, </span><span>чем </span><span>за </span><span>всем </span><span>миром </span><span>. </span><span>
#
#  </span><span>Давайте </span><span>сравнивать </span><span>
#
#  </span><span>За </span><span>2020 </span><span>год </span><span>ковид </span><span>унес </span><span>примерно </span><span>70 </span><span>000 </span><span>жизней </span><span>( </span><span>по </span><span>данным </span><span>статистики </span><span>яндекса </span><span>) </span><span>и </span><span>около </span><span>160 </span><span>000 </span><span>жизней </span><span>по </span><span>данным </span><span>Росстат </span><span>( </span><span>такие </span><span>же </span><span>данные </span><span>озвучивают </span><span>и </span><span>другие </span><span>официальные </span><span>источники </span><span>) </span><span>. </span><span>При </span><span>этом </span><span>молчит </span><span>Росстат </span><span>о </span><span>более </span><span>чем </span><span>1 </span><span>млн </span><span>смертей </span><span>от </span><span>сердечно </span><span>сосудистых </span><span>заболеваний </span><span>в </span><span>2020 </span><span>году </span><span>и </span><span>более </span><span>чем </span><span>300 </span><span>000 </span><span>случаев </span><span>смертей </span><span>от </span><span>онкологии </span><span>в </span><span>России </span><span>. </span><span>То </span><span>есть </span><span>ССЗ </span><span>и </span><span>Рак </span><span>становились </span><span>причинами </span><span>смертей </span><span>в </span><span>10 </span><span>раз </span><span>чаще </span><span>чем </span><span>ковид </span><span>. </span><span>
#
#  </span><span key=206 class="highlight pink" depth=0 id=Statistical_deception onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Statistical_deception</strong></span>                <span class="highlight__content"><span>Для </span> <span>сравнения </span> <span>, </span> <span>смертность </span></span></span><span>: </span><span>
#
#  </span><span>от </span><span>ССЗ </span><span>в </span><span>2020 </span><span>году </span><span>умирал </span><span>710 </span><span>человек </span><span>и </span><span>100 </span><span>000 </span><span>россиян </span><span>
#
#  </span><span>от </span><span>рака </span><span>в </span><span>России </span><span>умирали </span><span>250 </span><span>человек </span><span>из </span><span>100 </span><span>000 </span><span>граждан </span><span>
#
#  </span><span>от </span><span>ковида </span><span>в </span><span>2020 </span><span>году </span><span>100 </span><span>на </span><span>100 </span><span>000 </span><span>человек </span><span>
#
#  </span><span>Изученность </span><span>болезни </span><span>: </span><span>
#
#  </span><span key=249 class="highlight gray" depth=0 id=Sensational_and/or_provocative_headings onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Sensational_and/or_provocative_headings</strong></span>                <span class="highlight__content"><span>ковид-19 </span> <span>ново
# 110
# <div style="padding: 16px;"><span>ЛЖЕ </span><span>- </span><span>ПАНДЕМИЯ </span><span>КОРОНАВИРУСА </span><span>- </span><span>ВСЕМИРНАЯ </span><span>АФЁРА </span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ВИДЕО </span><span>: </span><span>ВАКЦИННЫЙ </span><span>НАНО </span><span>- </span><span>БИОЧИП </span><span>ВСЕХ </span><span>СПАСЁТ </span><span>. </span><span>нано </span><span>- </span><span>биочип </span><span>под </span><span>видом </span><span>вакцины </span><span>. </span><span>интервью </span><span>билла </span><span>гейтса </span><span>от </span><span>4.11.2021 </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>27 </span><span>мая </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_437%2Fall </span><span>) </span><span>
#
#  </span><span>ВИДЕО </span><span>: </span><span key=46 class="highlight gray" depth=0 id=Sensational_and/or_provocative_headings onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Sensational_and/or_provocative_headings</strong></span>                <span class="highlight__content"><span>ВАКЦИННЫЙ </span> <span>НАНО </span> <span>- </span> <span>БИОЧИП </span> <span>ВСЕХ </span> <span>СПАСЁТ </span> <span>. </span> <span>нано </span> <span>- </span> <span>биочип </span> <span>под </span> <span>видом </span> <span>вакцины </span> <span>. </span> <span>интервью </span> <span>билла </span> <span>гейтса </span> <span>от </span> <span>4.11.2021 </span> <span>. </span> <span>КОВИД </span> <span>- </span> <span>ФАШИСТ </span> <span>БИЛЛ </span> <span>ГЕЙТС </span> <span>СКАЗАЛ </span> <span>ПОЧТИ </span> <span>СЛЕДУЮЩЕЕ </span> <span>: </span> <span>БУРАТИНЫ </span> <span>ПЛАНЕТЫ </span> <span>ДУРАКОВ </span> <span>! </span> <span>НАНО </span> <span>- </span> <span>БИОЧИПЫ </span> <span>, </span> <span>КОТОРЫЕ </span> <span>МЫ </span> <span>ОБМАНОМ </span> <span>ВСТАВЛЯЕМ </span> <span>ВАМ </span> <span>ПОД </span> <span>ВИДОМ </span> <span>ВАКЦИН </span> <span>, </span> <span>ЭТО </span> <span>ОЧЕНЬ </span> <span>КРУТО </span> <span>И </span> <span>ЗДОРОВО </span> <span>! </span> <span>ВИРУСЫ </span> <span>БУДУТ </span> <span>ОТСКАКИВАТЬ </span> <span>ОТ </span> <span>ВАКЦИННОГО </span> <span>НАНО </span> <span>- </span> <span>БИОЧИПА </span> <span>, </span> <span>КАК </span> <span>МЯЧИКИ </span> <span>ОТ </span> <span>СТЕНКИ </span></span></span><span>. </span><span>
#
#
#
#  </span><span>( </span><span key=50 class="highlight blue" depth=0 id=Casting_Doubt onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Casting_Doubt</strong></span>                <span class="highlight__content"><span>неизвестно </span> <span>кто </span> <span>это </span> <span>- </span> <span>оригинал </span> <span>, </span> <span>двойник </span> <span>, </span> <span>клон </span> <span>, </span> <span>цифрововой </span> <span>аватар </span> <span>от </span> <span>ИИ </span> <span>, </span> <span>сделанный </span> <span>с </span> <span>помощью </span> <span>технологии </span> <span>видео </span> <span>- </span> <span>монтажа </span> <span>и </span> <span>обмана </span> <span>Deep </span> <span>Fake </span> <span>или </span> <span>старое </span> <span>интервью </span> <span>, </span> <span>выданное </span> <span>за </span> <span>новое </span></span></span><span>) </span><span>. </span><span>
#
#  </span><span>так </span><span>как </span><span>мы </span><span>знаём </span><span>, </span><span>что </span><span>билл </span><span>гейтс </span><span>был </span><span>казнён </span><span>1.10.2021 </span><span>. </span><span>см. </span><span>ГУАНТАНАМО </span><span>. </span><span>ОГНЕННАЯ </span><span>ЗЕМЛЯ </span><span>. </span><span>хроника </span><span>спецопераций </span><span>, </span><span>арестов </span><span>и </span><span>трибуналов </span><span>над </span><span>ковид </span><span>- </span><span>фашистами </span><span>. </span><span>
#
#  </span><span key=84 class="highlight tan" depth=0 id=Causal_Simplification onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Causal_Simplification</strong></span>                <span class="highlight__content"><span>СПРАВКА </span> <span>: </span> <span>- </span> <span>поскольку </span> <span>уже </span> <span>множество </span> <span>независимых </span> <span>учёных </span> <span>из </span> <span>разных </span> <span>стран </span> <span>провели </span> <span>научные </span> <span>исследования </span> <span>по </span> <span>ГМО </span> <span>- </span> <span>вакцинам </span> <span>, </span> <span>то </span> <span>скрывать </span> <span>и </span> <span>дальше </span> <span>уже </span> <span>нет </span> <span>смысла </span> <span>. </span> <span>мировое </span> <span>правительство </span> <span>через </span> <span>билла </span> <span>гейтса </span> <span>подтвердило </span> <span>, </span> <span>что </span> <span>их </span> <span>ГМО </span> <span>- </span> <span>вакцины </span> <span>вовсе </span> <span>не </span> <span>вакцины </span> <span>, </span> <span>а </span> <span>чипы </span> <span>, </span> <span>или </span> <span>если </span> <span>точнее </span> <span>, </span> <span>то </span> <span>нано </span> <span>- </span> <span>биочипы </span> <span>. </span> <span>биочипы </span> <span>состоят </span> <span>из </span> <span>нано </span> <span>- </span> <span>частиц </span> <span>, </span> <span>например </span> <span>из </span> <span>оксида </span> <span>графена </span> <span>. </span> <span>оксид </span> <span>графена </span> <span>самовоспроизводится </span> <span>в </span> <span>нано </span> <span>- </span> <span>структуры </span> <span>, </span> <span>в </span> <span>нано </span> <span>- </span> <span>блоки </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>оксид </span><span>графена </span><span>создаёт </span><span>надстройку </span><span>в </span><span>организме </span><span>человека </span><span>, </span><span>сходную </span><span>по </span><span>аналогии </span><span>с </span><span>операционной </span><span>системой </span><span>майкрософт </span><span>. </span><span>оксид </span><span>графена </span><span>, </span><span>попадая </span><span>в </span><span>организм </span><span>человека </span><span>, </span><span>растёт </span><span>питаясь </span><span>за </span><span>счёт </span><span>окружающей </span><span>структуры </span><span>организма </span><span>человека </span><span>. </span><span>
#
#  </span><span>- </span><span>в </span><span>вакцинном </span><span>нано </span><span>- </span><span>биочипе </span><span>, </span><span>заложены </span><span>механизмы </span><span>изменения </span><span>генома </span><span>- </span><span>ДНК </span><span>человека </span><span>. </span><span>то </span><span>есть </span><span>присутствуют </span><span>нано </span><span>- </span><span>инструменты </span><span>- </span><span>генетические </span><span>ножницы </span><span>и </span><span>нано </span><span>- </span><span>технология </span><span>КРИСПР </span><span>. </span><span>
#
#
#
#  </span><span>- </span><span>почему </span><span>био </span><span>? </span><span>потому </span><span>что </span><span>так </span><span>оно </span><span>и </span><span>есть </span><span>: </span><span>
#
#  </span><span>1 </span><span>) </span><span>поскольку </span><span>оксид </span><span>графена </span><span>биосовместим </span><span>с </span><span>организмом </span><span>человека </span><span>хотя </span><span>и </span><span>высокотоксичен </span><span>. </span><span>см. </span><span>ГРАФЕН </span><span>оксид </span><span>( </span><span>нано </span><span>- </span><span>чип </span><span>) </span><span>2 </span><span>) </span><span>струк
# 111
# <div style="padding: 16px;"><span>Еще </span><span>новости </span><span>последнего </span><span>времени </span><span>- </span><span>ковид </span><span>- </span><span>паспорта </span><span>и </span><span>чипы </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Ключи </span><span>разумения </span><span>. </span><span>Апокалипсис </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YHWLxFuJH1EZy621 </span><span>( </span><span>14.04.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Уважаемый </span><span>читатель </span><span>, </span><span>мы </span><span>живем </span><span>в </span><span>такое </span><span>время </span><span>, </span><span>когда </span><span>новости </span><span>, </span><span>характеризующие </span><span>наступление </span><span>" </span><span>последнего </span><span>времени </span><span>" </span><span>- </span><span>времени </span><span>перед </span><span>установлением </span><span>власти </span><span>антихриста </span><span>и </span><span>затем </span><span>Вторым </span><span>пришествием </span><span>Христа </span><span>, </span><span>выходят </span><span>чуть </span><span>ли </span><span>не </span><span>каждый </span><span>день </span><span>, </span><span>даже </span><span>несколько </span><span>раз </span><span>в </span><span>день </span><span>. </span><span>
#
#  </span><span>Приходится </span><span>очень </span><span>хорошо </span><span>отсеивать </span><span>информацию </span><span>, </span><span>потому </span><span>что </span><span>много </span><span>публикуется </span><span>различных </span><span>фейков </span><span>. </span><span>
#
#  </span><span>Мне </span><span>кажется </span><span>, </span><span>что </span><span>на </span><span>это </span><span>и </span><span>расчет </span><span>- </span><span>публиковать </span><span>огромную </span><span>массу </span><span>фейков </span><span>и </span><span>вместе </span><span>с </span><span>тем </span><span>вполне </span><span>реальные </span><span>новости </span><span>, </span><span>чтобы </span><span>снизить </span><span>у </span><span>людей </span><span>уровень </span><span>критической </span><span>оценки </span><span>событий </span><span>. </span><span>
#
#  </span><span>О </span><span>признаках </span><span>приближающей </span><span>власти </span><span>антихриста </span><span>я </span><span>писал </span><span>в </span><span>этой </span><span>статье </span><span>" </span><span>Признаки </span><span>приближающейся </span><span>власти </span><span>Антихриста </span><span>" </span><span>, </span><span>анализируя </span><span>некоторые </span><span>мировые </span><span>тренды </span><span>. </span><span>
#
#  </span><span>Буквально </span><span>на </span><span>днях </span><span>прочитал </span><span>сразу </span><span>несколько </span><span>новостей </span><span>, </span><span>некоторые </span><span>оказались </span><span>фейковыми </span><span>. </span><span>Например </span><span>, </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>вакцинах </span><span>будет </span><span>чип </span><span>от </span><span>Microsoft </span><span>оказалась </span><span>фейком </span><span>англоязычного </span><span>сатирического </span><span>  </span><span>сайта </span><span>. </span><span>
#
#  </span><span>Но </span><span>вот </span><span>новость </span><span>о </span><span>том </span><span>, </span><span>что </span><span>ученые </span><span>Пентагона </span><span>разработали </span><span>микрочип </span><span>, </span><span>который </span><span>вводится </span><span>под </span><span>кожу </span><span>и </span><span>диагностирует </span><span>COVID-19 </span><span>, </span><span>и </span><span>этот </span><span>микрочип </span><span>реально </span><span>очень </span><span>маленький </span><span>- </span><span>вполне </span><span>реальна </span><span>. </span><span>Ее </span><span>опубликовали </span><span>такие </span><span>известные </span><span>издания </span><span>как </span><span>  </span><span>the </span><span>SUN </span><span>, </span><span>  </span><span>NYPost </span><span>, </span><span>  </span><span>Independent </span><span>  </span><span key=218 class="highlight purple" depth=0 id=Appeal_to_authority onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Appeal_to_authority</strong></span>                <span class="highlight__content"><span>и </span> <span>другие </span></span></span><span>. </span><span>
#
#  </span><span>Будет </span><span>ли </span><span>этот </span><span>чип </span><span>начертанием </span><span>? </span><span>Нет </span><span>. </span><span>Но </span><span>все </span><span>это </span><span>звенья </span><span>в </span><span>одной </span><span>большой </span><span>цепочке </span><span>событий </span><span>, </span><span>как </span><span>и </span><span>другая </span><span>новость </span><span>их </span><span>этого </span><span>поста </span><span>. </span><span>
#
#  </span><span>Одновременно </span><span>с </span><span>этим </span><span>в </span><span>европейской </span><span>  </span><span>прессе </span><span>  </span><span>появляется </span><span>высказывание </span><span>Тьерри </span><span>Бретона </span><span>, </span><span>европейского </span><span>комиссара </span><span>, </span><span>возглавляющего </span><span>целевую </span><span>группу </span><span>ЕС </span><span>по </span><span>вакцинам </span><span>, </span><span>который </span><span>говорит </span><span>о </span><span>том </span><span>, </span><span>что </span><span>в </span><span>начале </span><span>лета </span><span>, </span><span>с </span><span>15 </span><span>июня </span><span>, </span><span>будет </span><span>запущен </span><span>общеевропейский </span><span>паспорт </span><span>здоровья </span><span>, </span><span>паспорт </span><span>вакцинации </span><span>, </span><span>который </span><span>будет </span><span>содержать </span><span>как </span><span>данные </span><span>о </span><span>мазках </span><span>тестирования </span><span>с </span><span>датами </span><span>и </span><span>результатами </span><span>, </span><span>так </span><span>и </span><span>с </span><span>информацией </span><span>о </span><span>вакцинировании </span><span>, </span><span>все </span><span>это </span><span>с </span><span>QR </span><span>кодами </span><span>. </span><span>Паспорт </span><span>позволит </span><span>путешествовать </span><span>и </span><span>давать </span><span>право </span><span>входа </span><span>в </span><span>публичные </span><span>места </span><span>. </span><span>
#
#  </span><span>Вот </span><span>такие </span><span>новости </span><span>всего </span><span>за </span><span>пару </span><span>дней </span><span>. </span><span>Признаки </span><span>ли </span><span>это </span><span>последнего </span><span>времени </span><span>? </span><span>Вероятно </span><span>да </span><span>. </span><span>
#
#  </span><span>Кстати </span><span>, </span><span>для </span><span>описания </span><span>слова </span><span>" </span><span>начертание </span><span>" </span><span>в </span><span>книге </span><span>Откровения </span><span>Иоанна </span><span>Богослова </span><span>используется </span><span>интересное </span><span>греческое </span><span>слово </span><span>- </span><span>  </span><span key=369 class="highlight blue" depth=0 id=Labelling onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Labelling</strong></span>                <span class="highlight__content"><span>хАрагма </span> <span>- </span> <span>клеймо </span> <span>, </span> <span>а </span> <span>также </span> <span>это </span> <span>слово </span> <span>имеет </span> <span>и </span> <span>другие </span> <span>значения </span></span></span><span>: </span><span>
#
#  </span><span key=372 class="highlight purple
# 115
# <div style="padding: 16px;"><span>Ковид </span><span>стоит </span><span>триллиарды </span><span>долларов </span><span>. </span><span>Правда </span><span>, </span><span>от </span><span>которой </span><span>не </span><span>убежать </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Родина </span><span>Слонов </span><span>; </span><span>URL </span><span>: </span><span>https://dzen.ru/a/YP5vrjuTmlH6WvYm </span><span>( </span><span>27.07.2021 </span><span>) </span><span>
#
#
#
#  </span><span>Дочитайте </span><span>эту </span><span>статью </span><span>до </span><span>конца </span><span>- </span><span>и </span><span>вы </span><span>согласитесь </span><span>, </span><span>что </span><span>коронавирус </span><span>стал </span><span>очень </span><span>своевременным </span><span>и </span><span>очень </span><span>выгодным </span><span>решением </span><span>. </span><span>И </span><span>знаете </span><span>, </span><span>для </span><span>кого </span><span>конкретно </span><span>? </span><span>
#
#  </span><span>Чтобы </span><span key=55 class="highlight blue" depth=0 id=Casting_Doubt onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Casting_Doubt</strong></span>                <span class="highlight__content"><span>объяснить </span> <span>, </span> <span>откуда </span> <span>автору </span> <span>пришло </span> <span>озарение </span> <span>на </span> <span>эту </span> <span>тему </span> <span>, </span> <span>нужно </span> <span>сообщить </span> <span>, </span> <span>что </span> <span>идёт </span> <span>пятый </span> <span>день </span> <span>моих </span> <span>мучений </span> <span>с </span> <span>этим </span> <span>заболеванием </span> <span>. </span> <span>На </span> <span>третий </span> <span>день </span> <span>сделал </span> <span>ПЦР </span> <span>- </span> <span>тест </span> <span>, </span> <span>на </span> <span>четвертый </span> <span>- </span> <span>тест </span> <span>вышел </span> <span>положительным </span> <span>. </span> <span>А </span> <span>ведь </span> <span>я </span> <span>так </span> <span>хорошо </span> <span>и </span> <span>удачно </span> <span>проскочил </span> <span>через </span> <span>первые </span> <span>две </span> <span>волны </span> <span>, </span> <span>что </span> <span>уже </span> <span>считал </span> <span>себя </span> <span>бессмертным </span> <span>и </span> <span>неуязвимым </span> <span>, </span> <span>как </span> <span>горец </span> <span>... </span> <span>Теперь </span> <span>— </span> <span>мучение </span> <span>- </span> <span>лечение </span> <span>, </span> <span>да </span> <span>ещё </span> <span>пришлось </span> <span>отказаться </span> <span>от </span> <span>экспедиции </span> <span>на </span> <span>Перевал </span> <span>Дятлова </span> <span>( </span> <span>а </span> <span>готовилась </span> <span>она </span> <span>полгода </span> <span>) </span> <span>, </span> <span>ну </span> <span>в </span> <span>- </span> <span>общем </span> <span>, </span> <span>расклад </span> <span>для </span> <span>старта </span> <span>мыслей </span> <span>был </span> <span>позитивный </span></span></span><span>... </span><span>
#
#  </span><span>Откуда </span><span>и </span><span>для </span><span>чего </span><span>могла </span><span>взяться </span><span>проклятая </span><span>ковидла </span><span>— </span><span>и </span><span>, </span><span>главное </span><span>, </span><span>когда </span><span>это </span><span>всё </span><span>нас </span><span>окончательно </span><span>минует </span><span>? </span><span>
#
#  </span><span>Помните </span><span>старый </span><span>анекдот </span><span>, </span><span>как </span><span>заработать </span><span>трём </span><span>программистам </span><span>? </span><span>Один </span><span>пишет </span><span>вирусы </span><span>, </span><span>второй </span><span>антивирусы </span><span>, </span><span>а </span><span>третий </span><span>- </span><span>программное </span><span>обеспечение </span><span>, </span><span>в </span><span>котором </span><span>всё </span><span>это </span><span>работает </span><span>. </span><span>
#
#  </span><span>Для </span><span key=109 class="highlight cobalt" depth=0 id=“you_should” onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>“you_should”</strong></span>                <span class="highlight__content"><span>тех </span> <span>, </span> <span>кто </span> <span>с </span> <span>ходу </span> <span>уже </span> <span>думает </span> <span>, </span> <span>что </span> <span>просёк </span> <span>нить </span> <span>разговора </span> <span>, </span> <span>можете </span> <span>сразу </span> <span>листнуть </span> <span>вниз </span> <span>, </span> <span>до </span> <span>комментариев </span> <span>, </span> <span>и </span> <span>там </span> <span>оставить </span> <span>отметку </span> <span>наподобие </span> <span>" </span> <span>Автор </span> <span>, </span> <span>браво </span> <span>, </span> <span>всё </span> <span>верняк </span> <span>, </span> <span>пиши </span> <span>исчо </span> <span>" </span> <span>или </span> <span>просто </span> <span>" </span> <span>Здесь </span> <span>был </span> <span>Вася </span> <span>" </span> <span>или </span> <span>даже </span> <span>" </span> <span>Как </span> <span>обычно </span> <span>, </span> <span>полная </span> <span>чушь </span> <span>" </span> <span>( </span> <span>последнее </span> <span>, </span> <span>правда </span> <span>, </span> <span>не </span> <span>столь </span> <span>эпично </span></span></span><span>) </span><span>. </span><span>
#
#  </span><span>А </span><span>тем </span><span>, </span><span>кто </span><span>решит </span><span>прочитать </span><span>полностью </span><span>- </span><span>вы </span><span>молодцы </span><span>, </span><span>я </span><span>заранее </span><span>вами </span><span>горжусь </span><span>, </span><span>пытливые </span><span>умы </span><span>. </span><span>
#
#
#
#  </span><span>Это </span><span key=134 class="highlight gray" depth=0 id=Hate_speech,slang,name_calling onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Hate_speech,slang,name_calling</strong></span>                <span class="highlight__content"><span>была </span> <span>, </span> <span>конечно </span> <span>, </span> <span>шутка </span> <span>, </span> <span>от </span> <span>моего </span> <span>любимого </span> <span>юмористического </span> <span>журнала </span> <span>" </span> <span>Красная </span> <span>Бурда </span> <span>" </span> <span>. </span> <span>А </span> <span>вот </span> <span>что </span> <span>не </span> <span>является </span> <span>шуткой </span> <span>, </span> <span>так </span> <span>это </span> <span>факт </span> <span>, </span> <span>что </span></span></span><span>  </span><span>вирус </span><span>- </span><span>то </span><span>напоминает </span><span>боевой </span><span>. </span><span>Это </span><span>было </span><span>понятно </span><span>, </span><span>когда </span><span>выяснилась </span><span>его </span><span>особенность </span><span>в </span><span>виде </span><span>отключения </span><span>обоняния </span><span>( </span><span>или </span><span>" </span><span>нюха </span><span>" </span><span>, </span><span>как </span><span>любят </span><span>говорить </span><span>в </span><span>России </span><span>) </span><span>- </span><span>интересненький </span><span>эксперимент </span><span>по </span><span>лишению </span><span>человека </span><span>конкретной </span><span>функции </span><span>( </span><span>сегодня </span><span>- </span><span>нос </span><span>, </span><span>завтра </span><span>- </span><span>руку </span><span>можно </span><span>отстегнуть </span><span>? </span><span>) </span><span>, </span><span>но </span><span>стало </span><sp
# 12
# <div style="padding: 16px;"><span>Кинология </span><span>для </span><span>каждого </span><span>. </span><span>Все </span><span>о </span><span>собаках </span><span>и </span><span>не </span><span>только </span><span>. </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>4 </span><span>января </span><span>( </span><span>) </span><span>
#
#
#
#  </span><span>ПОЧЕМУ </span><span>СОБАЧНИКАМ </span><span>НЕ </span><span>СТРАШЕН </span><span>КОРОНАВИРУС </span><span>. </span><span>Автор </span><span>Ирина </span><span>Видус </span><span>
#
#  </span><span>- </span><span>У </span><span>собачников </span><span>очень </span><span>сильный </span><span>иммунитет </span><span>, </span><span>ведь </span><span>они </span><span>рано </span><span>встают </span><span>и </span><span>ежедневно </span><span>гуляют </span><span>по </span><span>2 </span><span>- </span><span>3 </span><span>часа </span><span>в </span><span>любую </span><span>погоду </span><span>
#  </span><span>- </span><span>А </span><span>ещё </span><span>их </span><span>иммунитет </span><span>натренирован </span><span>, </span><span>ведь </span><span>он </span><span>каждый </span><span>день </span><span>сталкивается </span><span>с </span><span>кучей </span><span>бактерий </span><span>/ </span><span>вирусов </span><span>и </span><span>успешно </span><span>их </span><span>побеждает </span><span>. </span><span>
#  </span><span>- </span><span>У </span><span>собачника </span><span>крепкая </span><span>нервная </span><span>система </span><span>, </span><span>а </span><span>это </span><span>неплохой </span><span>щит </span><span>для </span><span>любой </span><span>инфекции </span><span>. </span><span>Собачник </span><span>каждый </span><span>день </span><span>противостоит </span><span>догхантерам </span><span>, </span><span>
#  </span><span>яжематерям </span><span>, </span><span>собаконенавистникам </span><span>и </span><span>не </span><span>теряет </span><span>бодрость </span><span>духа </span><span>и </span><span>оптимизм </span><span>. </span><span>Собачники </span><span>умеют </span><span>радоваться </span><span>каждому </span><span>пустяку </span><span>, </span><span>любить </span><span>природу </span><span>, </span><span>братьев </span><span>наших </span><span>меньших </span><span>. </span><span>Они </span><span>не </span><span>пойдут </span><span>скупать </span><span>гречку </span><span>и </span><span>туалетную </span><span>бумагу </span><span>. </span><span>Пожалуй </span><span>, </span><span>собачник </span><span>купит </span><span>новый </span><span>мячик </span><span>щенку </span><span>и </span><span>капли </span><span>с </span><span>ошейником </span><span>от </span><span>блох </span><span>и </span><span>клещей </span><span>для </span><span>взрослой </span><span>собаки </span><span>. </span><span>
#  </span><span>- </span><span>Собачники </span><span>живут </span><span>по </span><span>четкому </span><span>режиму </span><span>, </span><span>они </span><span>очень </span><span>рано </span><span>встают </span><span>, </span><span>выходят </span><span>гулять </span><span>с </span><span>собакой </span><span>в </span><span>одно </span><span>и </span><span>то </span><span>же </span><span>время </span><span>, </span><span>кормят </span><span>щенков </span><span>по </span><span>часам </span><span>. </span><span>Собачники </span><span>не </span><span>тусят </span><span>в </span><span>клубах </span><span>, </span><span>редко </span><span>проводят </span><span>время </span><span>в </span><span>ТЦ </span><span>, </span><span>не </span><span>жалуют </span><span>алкоголь </span><span>и </span><span>сигареты </span><span>, </span><span>потому </span><span>что </span><span>этот </span><span>запах </span><span>не </span><span>любят </span><span>их </span><span>хвостики </span><span>. </span><span>Обожают </span><span>поля </span><span>, </span><span>леса </span><span>, </span><span>походы </span><span>, </span><span>поездки </span><span>за </span><span>город </span><span>и </span><span>дачу </span><span>. </span><span>Могут </span><span>прилечь </span><span>днем </span><span>спать </span><span>вместе </span><span>с </span><span>любимыми </span><span>хвостиками </span><span>, </span><span>нагулявшись </span><span>в </span><span>лесу </span><span>. </span><span>Подобный </span><span>иммунный </span><span>щит </span><span>и </span><span>здоровый </span><span>образ </span><span>жизни </span><span>неплохо </span><span>противостоит </span><span>вирусам </span><span>. </span><span>
#  </span><span>- </span><span>Собачники </span><span>и </span><span>без </span><span>того </span><span>сидят </span><span>на </span><span>карантине </span><span>. </span><span>Сперва </span><span>исчезают </span><span>родственники </span><span>, </span><span>потом </span><span>" </span><span>друзья </span><span>" </span><span>, </span><span>затем </span><span>и </span><span>соседи </span><span>перестают </span><span>захаживать </span><span>. </span><span>Любимая </span><span>фраза </span><span>собачника:"чем </span><span>меньше </span><span>вокруг </span><span>народа </span><span>, </span><span>тем </span><span>лучше </span><span>для </span><span>моей </span><span>собаки </span><span>" </span><span>. </span><span>
#  </span><span>- </span><span>Собачник </span><span>смело </span><span>может </span><span>тереть </span><span>нос </span><span>и </span><span>глаза </span><span>рукой </span><span>. </span><span>Кожный </span><span>и </span><span>общий </span><span>иммунитет </span><span>собаковода </span><span>всегда </span><span>на </span><span>высоте </span><span>, </span><span>после </span><span>того </span><span>как </span><span>лицо </span><span>каждый </span><span>день </span><span>облизывает </span><span>любимая </span><span>собака </span><span>. </span><span>Тем </span><span>более </span><span>слюна </span><span>содержит </span><span>не </span><span>только </span><span>бактерии </span><span>, </span><span>но </span><span>и </span><span>лизоцим </span><span>, </span><span>повышающий </span><span>иммунитет </span><span>и </span><span>оказывающий </span><span>
#  </span><span>бактерицидное </span><span>действие </span><span>. </span><span>А </span><span>от </span><span>" </span><span>носоцелования </span><span>" </span><span>не </span><span>откажется </span><span>в </span><span>здравом </span><span>смысле </span><span>ни </span><span>один </span><span>владелец </span><span>пса </span><span>. </span><span>Так </span><span>же </span><span>многие </span><span>собачники </span><span>пускают </span><span>собак </span><span>в </span><span>постель </span><span>, </span><span>что </span><span>плавно </span><span>, </span><span>изо </span><span>дня </span><span>в </span><span>день </span><span>, </span><span>закаливает </span><span>их </span><span>иммунитет </span><span>. </span><span>А </span><span>ещё </span><span>собачники </span><span>лучше </span><span>высыпаются </span><span>с </span><span>питомцам </span><span>, </span><span>меньше </span><span>боятся </span><span>бытовых </span><span>проблем </span><span>и </span><span>реже </span><span>переживают </span><span>по </span><span>пустякам </span><span>. </span><span>
#  </span><span>- </span><span>Вирусы </span><span>и </span><span>бактерии </span><span>со </span><span>страхом </span><span>бегут </span><span>из </span><span>сумочки </span><span>собачника </span><span>, </span><span>прочь </span><span>от </span><span>его </span><span>гаджетов </span><span>и </span><span>телефона </span><span>. </span><span>Ведь </span><span>там </span><span>уже </span><span>живут </span><span>свои </span><span>матерые </span><span>бактерии </span><span>, </span><span>заселившиеся </span><span>после </span><span>залежалой </span><span>мумии </span><span>сосиски </span><span>, </span><span>заплесневелого </span><span>сыра </span><span>, </span><span>старого </span><span>корма </span><span>и
# 123
# <div style="padding: 16px;"><span>ЛЖЕ </span><span>- </span><span>ПАНДЕМИЯ </span><span>КОРОНАВИРУСА </span><span>- </span><span>ВСЕМИРНАЯ </span><span>АФЁРА </span><span>( </span><span>2022 </span><span>) </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span>Рикардо </span><span>Дельгадо </span><span>об </span><span>окончательном </span><span>заключении </span><span>экспертов </span><span>: </span><span>ВСЕ </span><span>СОВРЕМЕННЫЕ </span><span>" </span><span>ВАКЦИНЫ </span><span>" </span><span>СОДЕРЖАТ </span><span>ИСКЛЮЧИТЕЛЬНО </span><span>НАНО </span><span>- </span><span>ТЕХНОЛОГИИ </span><span>: </span><span>НАНО </span><span>- </span><span>РОУТЕРЫ </span><span>, </span><span>НАНО </span><span>- </span><span>РЕТЕННЫ </span><span>, </span><span>КОДЕКИ </span><span>, </span><span>НАНО </span><span>- </span><span>АНТЕННЫ </span><span>, </span><span>КОТОРЫЕ </span><span>ПЕРЕДАЮТ </span><span>МАК </span><span>- </span><span>АДРЕСА </span><span>НА </span><span>СЕРВЕР </span><span>ИИ </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>14 </span><span>апреля </span><span>( </span><span>https://vk.com/club202671499?w=wall-202671499_415%2Fall </span><span>) </span><span>
#
#
#
#  </span><span>НАУЧНАЯ </span><span>СУПЕР </span><span>ИНФОРМАЦИЯ </span><span>2021 </span><span>ГОДА </span><span>В </span><span>ВИДЕО </span><span>: </span><span>ОСНОВАТЕЛЬ </span><span>ПЯТОЙ </span><span>КОЛОННЫ </span><span>Рикардо </span><span>Дельгадо </span><span>об </span><span>окончательном </span><span>заключении </span><span>экспертов </span><span>: </span><span>ВСЕ </span><span>СОВРЕМЕННЫЕ </span><span>" </span><span>ВАКЦИНЫ </span><span>" </span><span>СОДЕРЖАТ </span><span>ИСКЛЮЧИТЕЛЬНО </span><span>НАНО </span><span>- </span><span>ТЕХНОЛОГИИ </span><span>: </span><span>НАНО </span><span>- </span><span>РОУТЕРЫ </span><span>, </span><span>НАНО </span><span>- </span><span>РЕТЕННЫ </span><span>, </span><span>КОДЕКИ </span><span>, </span><span>НАНО </span><span>- </span><span>АНТЕННЫ </span><span>, </span><span>КОТОРЫЕ </span><span>ПЕРЕДАЮТ </span><span>МАК </span><span>- </span><span>АДРЕСА </span><span>НА </span><span>СЕРВЕР </span><span>ИИ </span><span>. </span><span>Что </span><span>содержат </span><span>" </span><span>вакцины </span><span>" </span><span>и </span><span>как </span><span>это </span><span>влияет </span><span>на </span><span>человека </span><span>. </span><span>доктор </span><span>рикардо </span><span>дельгадо </span><span>. </span><span>
#
#  </span><span>СОДЕРЖАНИЕ </span><span>ВИДЕО </span><span>: </span><span>
#
#  </span><span>- </span><span>0.05 </span><span>- </span><span>большой </span><span>группой </span><span>учёных </span><span>в </span><span>течение </span><span>нескольких </span><span>месяцев </span><span>было </span><span>протестировано </span><span>био </span><span>и </span><span>генное </span><span>оружие </span><span>под </span><span>названием </span><span>" </span><span>вакцины </span><span>" </span><span>от </span><span>коронавируса </span><span>- </span><span>пфайзер </span><span>, </span><span>джансен </span><span>, </span><span>модерна </span><span>, </span><span>астразенека </span><span>, </span><span>и </span><span>выяснилось </span><span>, </span><span>что </span><span>они </span><span>к </span><span>вакцинам </span><span>не </span><span>имеют </span><span>никакого </span><span>отношения </span><span>и </span><span>содержат </span><span>исключительно </span><span>нано </span><span>- </span><span>технологии </span><span>: </span><span>
#
#  </span><span>- </span><span key=198 class="highlight blue" depth=0 id=Labelling onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Labelling</strong></span>                <span class="highlight__content"><span>нано </span> <span>- </span> <span>роутеры </span> <span>, </span> <span>которые </span> <span>передают </span> <span>МАК </span> <span>- </span> <span>адреса </span> <span>, </span> <span>и </span> <span>могут </span> <span>быть </span> <span>зарегистрированы </span> <span>в </span> <span>беспроводной </span> <span>технологии </span> <span>блютуф </span> <span>с </span> <span>помощью </span> <span>собственного </span> <span>мобильного </span> <span>телефона </span> <span>, </span> <span>и </span> <span>мобильного </span> <span>приложения </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span key=202 class="highlight tan" depth=0 id=Causal_Simplification onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Causal_Simplification</strong></span>                <span class="highlight__content"><span>мы </span> <span>также </span> <span>нашли </span> <span>нано </span> <span>- </span> <span>антенны </span> <span>и </span> <span>плазмонные </span> <span>антенны </span> <span>для </span> <span>усиления </span> <span>этих </span> <span>сигналов </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>также </span><span>были </span><span>выявлены </span><span>нано </span><span>- </span><span>ретенны </span><span>, </span><span>которые </span><span>действуют </span><span>как </span><span>выпрямительные </span><span>мосты </span><span>постоянного </span><span>тока </span><span>, </span><span>кодеки </span><span>и </span><span>некоторые </span><span>логические </span><span>элементы </span><span>для </span><span>шифрования </span><span>этих </span><span>нано </span><span>- </span><span>коммуникаций </span><span>от </span><span>нано </span><span>- </span><span>привитого </span><span>человека </span><span>- </span><span>покемона </span><span>на </span><span>удалённый </span><span>сервер </span><span>. </span><span>
#
#  </span><span>- </span><span key=245 class="highlight orange" depth=0 id=Obfuscation,vagueness,obscurantism onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Obfuscation,vagueness,obscurantism</strong></span>                <span class="highlight__content"><span>сырьём </span> <span>для </span> <span>разработки </span> <span>этих </span> <span>микроструктурных </span> <span>комплексов </span> <span>является </span> <span>оксид </span> <span>графена </span> <span>, </span> <span>наличие </span> <span>которого </span> <span>имеет </span> <span>решающее </span> <span>значение </span> <span>для </span> <span>самосборки </span> <span>указанных </span> <span>структурных </span> <span>комплексов </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>основными </span><span>механизмами </span><span>удаления </span><span>оксида </span><span>графена </span><span>из </span><span>организма </span><span>в </span><span>квантовых </span><span>точках </span><span>графена </span><span>являются </span><span>: </span><span>естественное </span><span>био </span><span>- </span><span>разложение </span><span>посредством </span><span>фермента </span><span>миелопероксидазы </span><span>и </span><span>механизм </span><span>теслафореза </span><span>, </span><span>который </span><span>представляет </span><span>собой </span><span>электромагнитные </span><span>поля </span><span>микроволнового </span><span>излучения </span><span>. </span><span>в </span><span>основном </span><span>исходящий </span><span>от </span><span>сигналов </span><span>мобильного </span><span>телефона </span><span>, </span><span>с </span><span>различными </span><span>частотными </span><span>качествами </span><span>. </span><span>
#
# ...
#
#
#
#
#
#  </span></div>
# 94
# <div style="padding: 16px;"><span>Всё </span><span>это </span><span>, </span><span>скорее </span><span>всего </span><span>, </span><span>вылезло </span><span>из </span><span>чьей </span><span>- </span><span>то </span><span>лаборатории </span><span>// </span><span>Яндекс </span><span>. </span><span>Дзен </span><span>. </span><span>Сергей </span><span>Михеев </span><span>; </span><span>URL </span><span>: </span><span>  </span><span>( </span><span>02.12.2022 </span><span>) </span><span>
#
#  </span><span>Первого </span><span>декабря </span><span>2019 </span><span>года </span><span>в </span><span>Ухане </span><span>был </span><span>зарегистрирован </span><span>первый </span><span>случай </span><span>пневмонии </span><span>неизвестной </span><span>этиологии </span><span>. </span><span>Это </span><span>произошло </span><span>три </span><span>года </span><span>назад </span><span>. </span><span>В </span><span>опубликованном </span><span>докладе </span><span>международного </span><span>союза </span><span>учёных </span><span>в </span><span>журнале </span><span>« </span><span>The </span><span>Lancet </span><span>» </span><span>говорится </span><span>, </span><span>что </span><span>одой </span><span>из </span><span>главнейших </span><span>версий </span><span>происхождения </span><span>COVID-19 </span><span>является </span><span>лабораторное </span><span>происхождение </span><span>. </span><span>
#
#  </span><span>По </span><span>поводу </span><span>журнала </span><span>« </span><span>The </span><span>Lancet </span><span>» </span><span>. </span><span>Я </span><span>ещё </span><span>тогда </span><span>говорил </span><span>о </span><span>том </span><span>, </span><span>что </span><span>происхождение </span><span>этого </span><span>вируса </span><span>крайне </span><span>подозрительное </span><span>. </span><span>Исключать </span><span>его </span><span>искусственное </span><span>происхождение </span><span>нельзя </span><span>. </span><span>Хотя </span><span>у </span><span>нас </span><span>многие </span><span>, </span><span>включая </span><span>и </span><span>наших </span><span>руководителей </span><span>, </span><span>говорили </span><span>, </span><span>что </span><span>это </span><span>маловероятно </span><span>. </span><span>И </span><span>вся </span><span>эта </span><span>шумиха </span><span>, </span><span>связанная </span><span>с </span><span>ним </span><span>, </span><span>явно </span><span>была </span><span>искусственно </span><span>подогреваема </span><span>. </span><span>Зачем </span><span>мы </span><span>к </span><span>ней </span><span>подключились </span><span>, </span><span>особенно </span><span>на </span><span>первом </span><span>этапе </span><span>, </span><span>для </span><span>меня </span><span>до </span><span>сих </span><span>пор </span><span>является </span><span>загадкой </span><span>. </span><span>
#
#  </span><span>Но </span><span>главное </span><span>сейчас </span><span>заключается </span><span>в </span><span>том </span><span>, </span><span>что </span><span>в </span><span>следующий </span><span>раз </span><span>надо </span><span>быть </span><span>умнее </span><span>. </span><span>Это </span><span>к </span><span>вопросу </span><span>о </span><span>том </span><span>: </span><span>« </span><span>Смотрите </span><span>, </span><span>все </span><span>побежали </span><span>, </span><span>и </span><span>мы </span><span>побежали </span><span>. </span><span>Европа </span><span>, </span><span>Америка </span><span>, </span><span>Китай </span><span>, </span><span>карантин </span><span>, </span><span>давай </span><span>всех </span><span>колоть </span><span>! </span><span>Давайте </span><span>и </span><span>мы </span><span>тоже </span><span>будем </span><span>всё </span><span>это </span><span>делать </span><span>! </span><span>» </span><span>. </span><span key=205 class="highlight tan" depth=0 id=Causal_Simplification onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Causal_Simplification</strong></span>                <span class="highlight__content"><span>А </span> <span>в </span> <span>итоге </span> <span>, </span> <span>началась </span> <span>СВО </span> <span>, </span> <span>и </span> <span>вирус </span> <span>закончился </span> <span>сам </span> <span>собой </span></span></span><span>. </span><span>
#
#  </span><span key=208 class="highlight brown" depth=0 id=Simplified_Interpretation onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Simplified_Interpretation</strong></span>                <span class="highlight__content"><span>Это </span> <span>как </span> <span>шутили </span> <span>, </span> <span>что </span> <span>Владимир </span> <span>Путин </span> <span>одним </span> <span>росчерком </span> <span>пера </span> <span>завершил </span> <span>пандемию </span> <span>коронавируса </span> <span>. </span> <span>Это </span> <span>говорит </span> <span>о </span> <span>простой </span> <span>вещи </span> <span>: </span> <span>может </span> <span>быть </span> <span>, </span> <span>и </span> <span>не </span> <span>надо </span> <span>было </span> <span>такой </span> <span>бешеной </span> <span>паники </span> <span>развивать </span> <span>, </span> <span>людей </span> <span>так </span> <span>напрягать </span> <span>, </span> <span>нервировать </span> <span>? </span> <span>И </span> <span>не </span> <span>надо </span> <span>было </span> <span>повторять </span> <span>всё </span> <span>то </span> <span>, </span> <span>что </span> <span>было </span> <span>навязано </span> <span>Всемирной </span> <span>организацией </span> <span>здравоохранения </span> <span>и </span> <span>поддержано </span> <span>всеми </span> <span>этими </span> <span>глобалистскими </span> <span>элитами </span> <span>. </span> <span>На </span> <span>самом </span> <span>деле </span> <span>, </span> <span>всё </span> <span>то </span> <span>, </span> <span>что </span> <span>здесь </span> <span>происходило </span> <span>по </span> <span>ковиду </span> <span>, </span> <span>это </span> <span>была </span> <span>калька </span> <span>с </span> <span>западных </span> <span>практик </span> <span>, </span> <span>а </span> <span>так </span> <span>же </span> <span>прямое </span> <span>выполнение </span> <span>указаний </span> <span>глобалистских </span> <span>организаций </span> <span>здравоохранения </span> <span>. </span> <span>Это </span> <span>первое </span></span></span><span>. </span><span>
#
#  </span><span>Второе </span><span>даже </span><span>интереснее </span><span>. </span><span>Вот </span><span>это </span><span>мнение </span><span>учёных </span><span>, </span><span>которые </span><span>раньше </span><span>так </span><span>не </span><span>думали </span><span>, </span><span>а </span><span>сейчас </span><span>почему </span><span>- </span><span>то </span><span>стали </span><span>так </span><span>думать </span><span>, </span><span>говорит </span><span>о </span><span>том </span><span>, </span><span>что </span><span>всё </span><span>это </span><span>, </span><span>скорее </span><span>всего </span><span>, </span><span>вылезло </span><span>из </span><span>чьей </span><span>- </span><span>то </span><span>лаборатории </span><span>. </span><span>Вот </span><span>это </span><span>же </span><span>, </span><span>как </span><span>мне </span><span>кажется </span><span>, </span><span>самое </span><span>важное </span><span>. </span><span>Надо </span><span>всё </span><span>- </span><span>таки </span><span>выяснить </span><span>, </span><span>из </span><span>чьей </span><span>лаборатории </span><span>вылезло </span><span>. </span><span>Специально </span><span>, </span><span>или </span><span>случайно </span><span>. </span><span>Кто </span><span>способствовал </span><span>распространению </span><span>? </span><span>С </span><span>какой </span><span>целью </span><span>разрабатыва
# 99
# <div style="padding: 16px;"><span>Преступления </span><span>ковид </span><span>- </span><span>фашистов </span><span>мирового </span><span>правит </span><span>- </span><span>ства </span><span>( </span><span>2022 </span><span>) </span><span>. </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span>КОВИД </span><span>- </span><span>ФАШИСТА </span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span>НЕОФАШИСТОВ </span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span>НОВЫХ </span><span>ГИТЛЕРОВ </span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>// </span><span>Запись </span><span>во </span><span>ВКонтакте </span><span>: </span><span>29 </span><span>ноября </span><span>( </span><span>https://vk.com/public201975126?w=wall-201975126_973 </span><span>) </span><span>
#
#
#
#  </span><span>ШКОЛА </span><span>- </span><span>КОНВЕЙЕР </span><span>КОВИД </span><span>- </span><span>ФАШИСТА </span><span>КЛАУСА </span><span>ШВАБА </span><span>ПО </span><span>ШТАМПОВКЕ </span><span>МЕДИЦИНСКИХ </span><span>НЕОФАШИСТОВ </span><span>ИЛИ </span><span>ПРОЩЕ </span><span>ГОВОРЯ </span><span>НОВЫХ </span><span>ГИТЛЕРОВ </span><span>ДЛЯ </span><span>УСТАНОВЛЕНИЯ </span><span>НОВОГО </span><span>МИРОВОГО </span><span>ПОРЯДКА </span><span>. </span><span>ВИДЕО </span><span>. </span><span>
#
#  </span><span>- </span><span>Школа </span><span>диктаторов </span><span>ковид </span><span>- </span><span>фашиста </span><span>Клауса </span><span>Шваба </span><span>( </span><span>ротшильда </span><span>) </span><span>, </span><span>или </span><span>план </span><span>великой </span><span>перезагрузки </span><span>. </span><span>9 </span><span>дек. </span><span>2021 </span><span>г. </span><span>
#
#  </span><span>- </span><span>новые </span><span>гитлеры </span><span>готовятся </span><span>в </span><span>ВЭФ </span><span>для </span><span>проведения </span><span>всемирных </span><span>спецопераций </span><span>: </span><span>
#
#  </span><span key=106 class="highlight blue" depth=0 id=Labelling onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Labelling</strong></span>                <span class="highlight__content"><span>лже-"вакцинация </span> <span>" </span> <span>, </span> <span>лже </span> <span>- </span> <span>ПЦР </span> <span>- </span> <span>тестизация </span> <span>, </span> <span>QR </span> <span>- </span> <span>кодизация </span> <span>, </span> <span>цифровизация </span> <span>, </span> <span>зомби- </span> <span>и </span> <span>НЛП </span> <span>- </span> <span>пропаганда </span> <span>существования </span> <span>пандемий </span> <span>, </span> <span>штаммов </span> <span>, </span> <span>вирусов </span> <span>, </span> <span>которые </span> <span>на </span> <span>самом </span> <span>деле </span> <span>не </span> <span>существуют </span> <span>, </span> <span>спонсирование </span> <span>на </span> <span>частном </span> <span>и </span> <span>государственном </span> <span>уровне </span> <span>лже </span> <span>- </span> <span>учёных </span> <span>, </span> <span>которые </span> <span>скрывают </span> <span>, </span> <span>что </span> <span>нано </span> <span>- </span> <span>частицы </span> <span>, </span> <span>нано </span> <span>- </span> <span>технологии </span> <span>и </span> <span>5 </span> <span>джи </span> <span>- </span> <span>смертоносны </span> <span>и </span> <span>вредны </span> <span>для </span> <span>здоровья </span> <span>и </span> <span>иммунной </span> <span>системы </span> <span>человека </span></span></span><span>. </span><span>
#
#
#
#  </span><span>- </span><span key=110 class="highlight red" depth=0 id=Appeal_to_Hypocrisy onmouseover="handleHighlightMouseOver(this)"                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">                <span class="highlight__label"><strong>Appeal_to_Hypocrisy</strong></span>                <span class="highlight__content"><span>Одна </span> <span>из </span> <span>целей </span> <span>нынешней </span> <span>политики </span> <span>мирового </span> <span>правительства </span> <span>, </span> <span>проводимой </span> <span>правительствами </span> <span>многих </span> <span>стран </span> <span>, </span> <span>состоит </span> <span>в </span> <span>том </span> <span>, </span> <span>чтобы </span> <span>разрушить </span> <span>бизнес </span> <span>малых </span> <span>и </span> <span>средних </span> <span>предпринимателей </span> <span>. </span> <span>Чтобы </span> <span>транснациональные </span> <span>корпорации </span> <span>- </span> <span>ТНК </span> <span>, </span> <span>базирующиеся </span> <span>в </span> <span>Соединенных </span> <span>Штатах </span> <span>и </span> <span>Китае </span> <span>, </span> <span>смогли </span> <span>монополизировать </span> <span>бизнес </span> <span>повсюду </span> <span>и </span> <span>превратить </span> <span>народный </span> <span>капитализм </span> <span>в </span> <span>рабовладельческий </span> <span>строй </span></span></span><span>. </span><span>
#
#  </span><span>- </span><span>друзья </span><span>, </span><span>вы </span><span>наверное </span><span>совсем </span><span>чокнулись </span><span>, </span><span>если </span><span>ничего </span><span>не </span><span>делаете </span><span>для </span><span>того </span><span>, </span><span>чтобы </span><span>эту </span><span>ковид </span><span>- </span><span>фашистскую </span><span>сволочь </span><span>посадить </span><span>на </span><span>скамью </span><span>подсудимых </span><span>на </span><span>новом </span><span>нюрнбергском </span><span>трибунале </span><span>. </span><span>когда </span><span>они </span><span>и </span><span>наличные </span><span>деньги </span><span>отменят </span><span>, </span><span>вы </span><span>тоже </span><span>это </span><span>примите </span><span>? </span><span>отмена </span><span>денег </span><span>- </span><span>это </span><span>цель </span><span>коммунистов </span><span>, </span><span>а </span><span>не </span><span>капиталистов </span><span>. </span><span>
#
#  </span><span>- </span><span>где </span><span>работа </span><span>по </span><span>созданию </span><span>комитетов </span><span>избирателей </span><span>для </span><span>отзыва </span><span>депутатов </span><span>и </span><span>властей </span><span>? </span><span>где </span><span>митинги </span><span>и </span><span>демонстрации </span><span>? </span><span>где </span><span>борьба </span><span>? </span><span>да </span><span>, </span><span>есть </span><span>борцы </span><span>, </span><span>но </span><span>их </span><span>мало </span><span>. </span></div>
